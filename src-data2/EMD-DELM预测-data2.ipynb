# %% [markdown]
# ### 运行前先装一个PyEMD库     是pip install pyemd pip install PyEMD，还是pip install EMD-signal 试着装哪个成功

# %%
# 调用相关库
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import pandas as pd
from math import sqrt
from numpy import concatenate
import matplotlib.pyplot as plt
import numpy as np
import random
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from PyEMD import EMD, Visualisation
from scipy.io import savemat,loadmat
from sklearn.metrics import mean_squared_error, mean_absolute_error
from pandas import DataFrame
from pandas import concat
import numpy
import os
import copy
import scipy as spy
import math
from scipy.spatial.distance import cdist
from numpy import dot, exp

# %%
# 转换成监督数据，将每个特征转换成21列数据，20->1，20组预测一组
def series_to_supervised(data, n_in=20, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]  #计算特征的数量
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    # 将20组输入数据依次向下移动20,19,...3,2,1行，将数据加入cols列表（技巧：(n_in, 0, -1)中的-1指倒序循环，步长为1）
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    # 将一组输出数据加入cols列表（技巧：其中i=0）
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # cols列表(list)中现在有21块经过下移后的数据(即：df(-20),df(-19),...df(-2),df(-1),df)，将四块数据按列 并排合并
    agg = pd.concat(cols, axis=1)
    # 给合并后的数据添加列名
    agg.columns = names
    # print(agg)
    # 删除NaN值列
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
class DELM(object):

    def __init__(self, input_size,hidden_sizes,output_size,C,TF):
        # 初始化
        '''
            input_size:输入层节点数
            hidden_sizes:各隐含层节点数，也是各elm-ae的隐含层节点数
            output_size:输出层节点数
            C ： L2 正则化系数
            TF： 激活函数
        '''
        self._sizes = hidden_sizes
        self._l2penalty=C
        self.TF=TF 
        self.elmae=[]
        self.w=[]
        
        for i,size in enumerate(self._sizes + [output_size]):
            
            # 采样正交随机数进行网络权重初始化
            
            if input_size>=size:
                IW=spy.linalg.orth(np.random.rand(input_size,size)*2-1)
            else:
                IW=(np.random.rand(input_size,size)*2-1).T
                IW=spy.linalg.orth(IW).T
            # bias
            B=spy.linalg.orth(np.random.rand(size,1)*2-1)
            
            self.w.append(IW)
            
            if i< len(self._sizes + [output_size])-1:
                weight={'w':IW,'b':B}
                self.elmae.append(weight)
            
            input_size = size
    #无监督预训练各个ELM-AE
    def pretrain(self,X):
        self.elm_ae_weigth_list=[]#保存训练好的elmae的输出层权重 ，用于DELM初始化
        nsample=X.shape[0]
        for i in range(len(self.elmae)):
            IW=self.elmae[i]['w']
            B=self.elmae[i]['b']
            
            bias_matrix=np.tile(B,nsample).T
            
            tempH = np.dot(X,IW)+bias_matrix
            
            if self.TF=='sigmoid':
                H = 1. / (1. + np.exp(-tempH))
                
            elif self.TF=='sin':
                H=np.sin(tempH)
            # cal the output weights by least square method
            interval=(np.dot(H.T,H)+np.eye(IW.shape[1])/self._l2penalty)
            beta = np.dot(np.dot(np.linalg.pinv(interval) ,H.T),X)
            
            
            W=np.linalg.pinv(beta)
            # W = beta.T
            self.elm_ae_weigth_list.append(W)
            X=X.dot(W)
#                
    # 将训练好的elm-ae的输出层权重用于初始化delm
    def load_from_elm_aes(self):
        for i in range(len(self._sizes)):
            self.w[i] = self.elm_ae_weigth_list[i]
        
    # Training delm
    def train(self,X,Y):
        self.load_from_elm_aes()#注释掉这句 就不会采用训练好的elm-ae输出层权重对delm进行初始化
        
        
        H=[]
        input_=X
        a=len(self._sizes)
        
        for i in range(a):
            H=np.dot(input_,self.w[i])
            input_=H

        interval=np.dot(H.T,H)+np.eye(H.shape[1])/self._l2penalty
        
        beta = np.dot(np.dot(np.linalg.pinv(interval) ,H.T),Y)
        
        self.w[-1]=beta
        
    def predict(self,teX):
        H=[]
        input_=teX
        a=len(self.w)
        
        for i in range(a):
            H=np.dot(input_,self.w[i])
            input_=H
        return H

# %%
dataset = pd.read_excel("816480.xlsx")
fratures_Corrected_irradiance = [
    'Flow (Veh/5 Minutes)'
]
values = dataset[fratures_Corrected_irradiance].values
n_features=1 #特征数量

# %%
values = values.astype('float32')
close = values

# %%
close=close.reshape(-1,1)
close.shape
# Out:
# (1440, 1)

# %%
emd = EMD()   
emd.emd(close.reshape(-1))
imfs_close, res_close = emd.get_imfs_and_residue()

t = np.arange(0, 1440, 1)
vis = Visualisation()
vis.plot_imfs(imfs=imfs_close, residue=res_close, t=t, include_residue=True)
# vis.plot_instant_freq(t, imfs=imfs)
vis.show()
# Out:
# D:\SoftWare\anaconda\lib\site-packages\PyEMD\Visualisation.py:77: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()
# D:\SoftWare\anaconda\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
prediction_test = []
actual_test = []

for imf in imfs_close:
    imf=imf.reshape(-1,1)
    imf=pd.DataFrame(imf)
    data_=imf.values
    data_ = data_.astype('float32')
    # 标准化/放缩 特征值在（0,1）之间
    scaler = StandardScaler()
    scaled = scaler.fit_transform(data_)
    
    n_in = 3
    n_out = 1
    # 构造一个20->1的监督学习型数据
    reframed = series_to_supervised(scaled, n_in=n_in, n_out=n_out)
    values=reframed.values
    
    #训练集和测试集的划分比例
    ratio=0.8 
    N=int(len(values) *ratio)
    train = values[:N, :]
    test = values[N:, :]

    # 划分输入和输出,split into input and outputs
    n_obs = n_in * n_features
    train_X, train_y = train[:, :-1], train[:, -1]
    test_X, test_y = test[:, :-1], test[:, -1]
    print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
    train_y=train_y.reshape(-1,1)
    
    
        # In[] 参数设置
    hidden_sizes = [5,5]  #几个数就是几个隐含层，n个隐含层各自的节点就是[n1;n2;n3;n4;....nn]
    input_size = train_X.shape[1] #输入层节点数
    output_size= train_y.shape[1]#输出层节点数
    C=np.inf #L2正则化系数
    TF='sin'#激活函数       "sig"
    
    # In[3]: 训练
    Net = DELM(input_size,hidden_sizes, output_size, C,TF) #construct a delm
    Net.pretrain(train_X)#train elmae
    Net.train(train_X,train_y)#train delm
    
    
    
    #预测
    yhat = Net.predict(test_X)
    yhat=yhat.reshape(-1,1)
    # 对预测结果进行反归一化
    inv_yhat = scaler.inverse_transform(yhat)
    prediction_test.append(inv_yhat)
    # 将真实列据进行反归一化
    test_y=test_y.reshape(-1,1)
    inv_y = scaler.inverse_transform(test_y)
    actual_test.append(inv_y)
    
    





#####残差
imf=res_close.reshape(-1,1)
imf=imf.reshape(-1,1)
imf=pd.DataFrame(imf)
data_=imf.values
data_ = data_.astype('float32')
#    标准化/放缩 特征值在（0,1）之间
scaler = StandardScaler()
scaled = scaler.fit_transform(data_)
    
n_in = 3
n_out = 1
# 构造一个20->1的监督学习型数据
reframed = series_to_supervised(scaled, n_in=n_in, n_out=n_out)
values=reframed.values
    
#训练集和测试集的划分比例
ratio=0.8 
N=int(len(values) *ratio)
train = values[:N, :]
test = values[N:, :]

# 划分输入和输出,split into input and outputs
n_obs = n_in * n_features
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
train_y=train_y.reshape(-1,1)
    
        # In[] 参数设置
hidden_sizes = [5,5]  #几个数就是几个隐含层，n个隐含层各自的节点就是[n1;n2;n3;n4;....nn]
input_size = train_X.shape[1] #输入层节点数
output_size= train_y.shape[1]#输出层节点数
C=np.inf #L2正则化系数
TF='sin'#激活函数       "sig"
    
# In[3]: 训练
Net = DELM(input_size,hidden_sizes, output_size, C,TF) #construct a delm
Net.pretrain(train_X)#train elmae
Net.train(train_X,train_y)#train delm
    
    
    
#预测
yhat = Net.predict(test_X)
yhat=yhat.reshape(-1,1)
# 对预测结果进行反归一化
inv_yhat = scaler.inverse_transform(yhat)
prediction_test.append(inv_yhat)
# 将真实列据进行反归一化
test_y=test_y.reshape(-1,1)
inv_y = scaler.inverse_transform(test_y)
actual_test.append(inv_y)
# Out:
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)

# %%
mean_pre_test = []                    

for i in range(0,len(prediction_test[0])):
    sum = 0
    for j in range(0,len(prediction_test)):
        sum = sum + prediction_test[j][i]

    mean_pre_test.append(sum)
        
mean_pre_test
# Out:
# [array([127.25582872]),
#  array([129.65088173]),
#  array([140.09044386]),
#  array([144.93285516]),
#  array([136.25424756]),
#  array([138.46091803]),
#  array([139.97633123]),
#  array([145.83481501]),
#  array([142.59407629]),
#  array([124.3627445]),
#  array([104.64863084]),
#  array([94.83975683]),
#  array([87.38217436]),
#  array([87.80462948]),
#  array([80.63466436]),
#  array([95.11048847]),
#  array([92.81629277]),
#  array([85.62826216]),
#  array([71.22970652]),
#  array([72.47371655]),
#  array([74.53796576]),
#  array([75.00829167]),
#  array([82.94859746]),
#  array([67.29036937]),
#  array([66.79474231]),
#  array([79.69418948]),
#  array([82.68585652]),
#  array([66.11364556]),
#  array([63.99314443]),
#  array([65.23203251]),
#  array([65.25076402]),
#  array([68.31726295]),
#  array([64.73471989]),
#  array([64.90305545]),
#  array([64.83854838]),
#  array([60.51355411]),
#  array([58.99943035]),
#  array([51.78541414]),
#  array([50.82738539]),
#  array([61.79203135]),
#  array([70.93905872]),
#  array([80.28236206]),
#  array([87.71765211]),
#  array([103.71396137]),
#  array([113.40606423]),
#  array([125.76015367]),
#  array([121.62099281]),
#  array([105.33473112]),
#  array([85.75824035]),
#  array([82.17320575]),
#  array([99.35822672]),
#  array([112.5077613]),
#  array([109.48897429]),
#  array([93.74858472]),
#  array([129.85381131]),
#  array([179.71738196]),
#  array([207.69895611]),
#  array([202.14591207]),
#  array([192.50498663]),
#  array([168.59506837]),
#  array([144.94636128]),
#  array([132.60695493]),
#  array([168.78930536]),
#  array([199.43476811]),
#  array([219.87726181]),
#  array([221.06386264]),
#  array([229.81681179]),
#  array([265.50396547]),
#  array([328.83328702]),
#  array([361.07346883]),
#  array([365.75382911]),
#  array([347.67679791]),
#  array([331.64491283]),
#  array([316.65062426]),
#  array([300.81718652]),
#  array([291.06556528]),
#  array([292.48872087]),
#  array([310.74877558]),
#  array([349.90413503]),
#  array([398.91710951]),
#  array([440.8850216]),
#  array([460.41395138]),
#  array([462.90519945]),
#  array([440.6828892]),
#  array([417.82652567]),
#  array([402.06378002]),
#  array([421.41009856]),
#  array([437.92461407]),
#  array([451.63497411]),
#  array([464.67192252]),
#  array([492.93195235]),
#  array([525.97987352]),
#  array([546.95917987]),
#  array([532.95885774]),
#  array([528.954192]),
#  array([507.84522602]),
#  array([448.93491228]),
#  array([379.39059419]),
#  array([363.89398601]),
#  array([430.21740407]),
#  array([449.35094368]),
#  array([443.55040903]),
#  array([435.64910574]),
#  array([420.2442732]),
#  array([414.51268424]),
#  array([432.61408016]),
#  array([461.32324616]),
#  array([435.74843322]),
#  array([403.03107967]),
#  array([375.40962042]),
#  array([374.99098725]),
#  array([409.06934533]),
#  array([444.59968043]),
#  array([447.72058961]),
#  array([417.43310411]),
#  array([413.29426962]),
#  array([422.02202183]),
#  array([443.92824303]),
#  array([435.07910203]),
#  array([420.12616316]),
#  array([421.06623642]),
#  array([442.26711036]),
#  array([456.18934942]),
#  array([457.16480445]),
#  array([432.05183843]),
#  array([416.58884318]),
#  array([410.67685535]),
#  array([440.51482205]),
#  array([454.77949374]),
#  array([460.06112353]),
#  array([458.88528766]),
#  array([454.10095918]),
#  array([463.50169988]),
#  array([472.84797381]),
#  array([483.81388967]),
#  array([486.03834934]),
#  array([490.4432035]),
#  array([477.06812802]),
#  array([466.92357292]),
#  array([465.0696531]),
#  array([471.50992721]),
#  array([493.37000751]),
#  array([514.37049581]),
#  array([527.06511134]),
#  array([532.35295858]),
#  array([531.27563563]),
#  array([513.23418473]),
#  array([513.05790479]),
#  array([517.60297915]),
#  array([527.00650901]),
#  array([543.79031155]),
#  array([546.54396065]),
#  array([548.774038]),
#  array([535.88941626]),
#  array([543.56895586]),
#  array([550.91737987]),
#  array([563.55250245]),
#  array([577.73478166]),
#  array([581.70887915]),
#  array([576.26204041]),
#  array([562.11362211]),
#  array([540.77987884]),
#  array([532.0781102]),
#  array([530.28754012]),
#  array([541.64045913]),
#  array([551.42996644]),
#  array([546.59763619]),
#  array([535.53055722]),
#  array([537.40480869]),
#  array([534.4092277]),
#  array([523.91394339]),
#  array([511.42499199]),
#  array([523.21934472]),
#  array([541.96420554]),
#  array([561.93726201]),
#  array([551.50225419]),
#  array([524.3700346]),
#  array([484.373565]),
#  array([494.93991952]),
#  array([516.43385045]),
#  array([536.33708586]),
#  array([530.89537647]),
#  array([530.7054876]),
#  array([534.76667933]),
#  array([545.58610326]),
#  array([557.75065837]),
#  array([561.59124844]),
#  array([555.26440837]),
#  array([524.20983258]),
#  array([499.15416119]),
#  array([484.4825044]),
#  array([516.75101314]),
#  array([511.57202119]),
#  array([498.03545879]),
#  array([492.40664514]),
#  array([502.94593963]),
#  array([518.42318989]),
#  array([510.72693192]),
#  array([504.29575652]),
#  array([506.37165785]),
#  array([511.36678043]),
#  array([501.34306356]),
#  array([477.91653291]),
#  array([469.82752028]),
#  array([480.5443099]),
#  array([502.01763539]),
#  array([500.19850273]),
#  array([469.27992801]),
#  array([453.01959325]),
#  array([463.97832685]),
#  array([493.32326922]),
#  array([497.82675278]),
#  array([481.58022421]),
#  array([453.66351484]),
#  array([468.04469747]),
#  array([535.61285144]),
#  array([539.6860479]),
#  array([490.47731284]),
#  array([469.3039481]),
#  array([491.1979415]),
#  array([459.61743869]),
#  array([474.15250563]),
#  array([509.37712664]),
#  array([509.72255772]),
#  array([498.17821298]),
#  array([481.67055371]),
#  array([485.95035868]),
#  array([431.15479563]),
#  array([385.14425389]),
#  array([406.06174721]),
#  array([471.14245331]),
#  array([516.11456947]),
#  array([515.92956245]),
#  array([524.88684867]),
#  array([499.7172584]),
#  array([464.10027308]),
#  array([440.75850189]),
#  array([430.19672295]),
#  array([424.71999019]),
#  array([416.30439944]),
#  array([421.2507539]),
#  array([404.29978146]),
#  array([403.06294615]),
#  array([416.20006977]),
#  array([420.10130183]),
#  array([419.64720171]),
#  array([409.2408586]),
#  array([394.95784954]),
#  array([382.35446125]),
#  array([389.44767462]),
#  array([415.24663188]),
#  array([436.68122247]),
#  array([448.52440281]),
#  array([439.27660744]),
#  array([427.65385727]),
#  array([417.58916908]),
#  array([416.56625971]),
#  array([429.81979343]),
#  array([432.05840698]),
#  array([409.49816726]),
#  array([384.43620772]),
#  array([374.66798596]),
#  array([354.16449826]),
#  array([338.16144222]),
#  array([338.18024018]),
#  array([344.81014111]),
#  array([355.98602399]),
#  array([354.92731901]),
#  array([343.70788282]),
#  array([326.41411114]),
#  array([308.09001516]),
#  array([303.92844013]),
#  array([311.37836793]),
#  array([303.14041146]),
#  array([277.52949694]),
#  array([236.11849851]),
#  array([250.27806107]),
#  array([282.85813197]),
#  array([276.59153916]),
#  array([239.10346967]),
#  array([232.15713576]),
#  array([219.71006426]),
#  array([212.53144816]),
#  array([208.72661987]),
#  array([218.02403746]),
#  array([230.59148474]),
#  array([228.64568871]),
#  array([216.17482149])]

# %%
mean_actual_test = []

for i in range(0,len(actual_test[0])):
    sum = 0
    for j in range(0,len(actual_test)):
        sum = sum + actual_test[j][i]

    mean_actual_test.append(sum)
        
mean_actual_test
# Out:
# [array([114.], dtype=float32),
#  array([104.99997], dtype=float32),
#  array([91.], dtype=float32),
#  array([176.], dtype=float32),
#  array([141.], dtype=float32),
#  array([111.], dtype=float32),
#  array([108.], dtype=float32),
#  array([111.], dtype=float32),
#  array([122.], dtype=float32),
#  array([135.99998], dtype=float32),
#  array([89.000015], dtype=float32),
#  array([105.], dtype=float32),
#  array([83.999985], dtype=float32),
#  array([89.], dtype=float32),
#  array([79.], dtype=float32),
#  array([102.], dtype=float32),
#  array([107.], dtype=float32),
#  array([76.], dtype=float32),
#  array([84.999985], dtype=float32),
#  array([71.], dtype=float32),
#  array([78.], dtype=float32),
#  array([75.999985], dtype=float32),
#  array([84.], dtype=float32),
#  array([57.000015], dtype=float32),
#  array([85.], dtype=float32),
#  array([71.], dtype=float32),
#  array([83.], dtype=float32),
#  array([60.999985], dtype=float32),
#  array([61.000015], dtype=float32),
#  array([65.000015], dtype=float32),
#  array([67.], dtype=float32),
#  array([82.999985], dtype=float32),
#  array([70.], dtype=float32),
#  array([53.], dtype=float32),
#  array([72.], dtype=float32),
#  array([71.], dtype=float32),
#  array([52.000015], dtype=float32),
#  array([59.000015], dtype=float32),
#  array([57.000015], dtype=float32),
#  array([57.000015], dtype=float32),
#  array([77.999985], dtype=float32),
#  array([75.], dtype=float32),
#  array([85.], dtype=float32),
#  array([109.000015], dtype=float32),
#  array([106.], dtype=float32),
#  array([119.], dtype=float32),
#  array([131.], dtype=float32),
#  array([112.], dtype=float32),
#  array([81.], dtype=float32),
#  array([87.], dtype=float32),
#  array([106.], dtype=float32),
#  array([104.000015], dtype=float32),
#  array([113.000015], dtype=float32),
#  array([87.], dtype=float32),
#  array([165.99998], dtype=float32),
#  array([152.], dtype=float32),
#  array([185.00002], dtype=float32),
#  array([200.], dtype=float32),
#  array([202.99998], dtype=float32),
#  array([150.], dtype=float32),
#  array([154.], dtype=float32),
#  array([130.99998], dtype=float32),
#  array([162.], dtype=float32),
#  array([209.], dtype=float32),
#  array([228.], dtype=float32),
#  array([207.], dtype=float32),
#  array([248.00002], dtype=float32),
#  array([261.], dtype=float32),
#  array([334.], dtype=float32),
#  array([389.], dtype=float32),
#  array([359.], dtype=float32),
#  array([330.], dtype=float32),
#  array([290.], dtype=float32),
#  array([270.], dtype=float32),
#  array([274.], dtype=float32),
#  array([299.], dtype=float32),
#  array([327.], dtype=float32),
#  array([330.], dtype=float32),
#  array([347.], dtype=float32),
#  array([377.], dtype=float32),
#  array([448.], dtype=float32),
#  array([474.], dtype=float32),
#  array([487.], dtype=float32),
#  array([422.], dtype=float32),
#  array([417.], dtype=float32),
#  array([379.], dtype=float32),
#  array([408.], dtype=float32),
#  array([471.], dtype=float32),
#  array([502.], dtype=float32),
#  array([446.], dtype=float32),
#  array([450.], dtype=float32),
#  array([483.], dtype=float32),
#  array([588.], dtype=float32),
#  array([521.], dtype=float32),
#  array([498.], dtype=float32),
#  array([523.], dtype=float32),
#  array([412.], dtype=float32),
#  array([388.], dtype=float32),
#  array([373.], dtype=float32),
#  array([444.], dtype=float32),
#  array([416.], dtype=float32),
#  array([434.], dtype=float32),
#  array([455.], dtype=float32),
#  array([399.], dtype=float32),
#  array([436.], dtype=float32),
#  array([430.], dtype=float32),
#  array([448.], dtype=float32),
#  array([461.], dtype=float32),
#  array([392.], dtype=float32),
#  array([354.], dtype=float32),
#  array([350.], dtype=float32),
#  array([424.], dtype=float32),
#  array([425.], dtype=float32),
#  array([434.], dtype=float32),
#  array([420.], dtype=float32),
#  array([428.], dtype=float32),
#  array([408.], dtype=float32),
#  array([470.], dtype=float32),
#  array([473.], dtype=float32),
#  array([393.], dtype=float32),
#  array([430.], dtype=float32),
#  array([467.], dtype=float32),
#  array([436.], dtype=float32),
#  array([451.], dtype=float32),
#  array([454.], dtype=float32),
#  array([451.], dtype=float32),
#  array([393.], dtype=float32),
#  array([477.], dtype=float32),
#  array([446.], dtype=float32),
#  array([433.], dtype=float32),
#  array([474.], dtype=float32),
#  array([464.], dtype=float32),
#  array([450.], dtype=float32),
#  array([479.], dtype=float32),
#  array([503.], dtype=float32),
#  array([475.], dtype=float32),
#  array([506.], dtype=float32),
#  array([478.], dtype=float32),
#  array([449.], dtype=float32),
#  array([479.], dtype=float32),
#  array([467.], dtype=float32),
#  array([474.], dtype=float32),
#  array([535.], dtype=float32),
#  array([546.], dtype=float32),
#  array([513.], dtype=float32),
#  array([553.], dtype=float32),
#  array([488.], dtype=float32),
#  array([507.], dtype=float32),
#  array([539.], dtype=float32),
#  array([512.], dtype=float32),
#  array([561.], dtype=float32),
#  array([534.], dtype=float32),
#  array([556.], dtype=float32),
#  array([547.], dtype=float32),
#  array([541.], dtype=float32),
#  array([541.], dtype=float32),
#  array([549.], dtype=float32),
#  array([592.], dtype=float32),
#  array([573.], dtype=float32),
#  array([565.], dtype=float32),
#  array([567.], dtype=float32),
#  array([532.], dtype=float32),
#  array([541.], dtype=float32),
#  array([519.], dtype=float32),
#  array([523.], dtype=float32),
#  array([573.], dtype=float32),
#  array([567.], dtype=float32),
#  array([507.], dtype=float32),
#  array([533.], dtype=float32),
#  array([556.], dtype=float32),
#  array([558.], dtype=float32),
#  array([510.], dtype=float32),
#  array([505.], dtype=float32),
#  array([533.], dtype=float32),
#  array([570.], dtype=float32),
#  array([535.], dtype=float32),
#  array([525.], dtype=float32),
#  array([478.], dtype=float32),
#  array([517.], dtype=float32),
#  array([492.], dtype=float32),
#  array([537.], dtype=float32),
#  array([563.], dtype=float32),
#  array([523.], dtype=float32),
#  array([509.], dtype=float32),
#  array([509.], dtype=float32),
#  array([515.], dtype=float32),
#  array([519.], dtype=float32),
#  array([566.], dtype=float32),
#  array([489.], dtype=float32),
#  array([521.], dtype=float32),
#  array([477.], dtype=float32),
#  array([532.], dtype=float32),
#  array([497.], dtype=float32),
#  array([484.], dtype=float32),
#  array([506.], dtype=float32),
#  array([493.], dtype=float32),
#  array([525.], dtype=float32),
#  array([536.], dtype=float32),
#  array([481.], dtype=float32),
#  array([481.], dtype=float32),
#  array([518.], dtype=float32),
#  array([526.], dtype=float32),
#  array([454.], dtype=float32),
#  array([497.], dtype=float32),
#  array([504.], dtype=float32),
#  array([489.], dtype=float32),
#  array([505.], dtype=float32),
#  array([476.], dtype=float32),
#  array([439.], dtype=float32),
#  array([489.], dtype=float32),
#  array([520.], dtype=float32),
#  array([469.00003], dtype=float32),
#  array([480.], dtype=float32),
#  array([496.99997], dtype=float32),
#  array([451.], dtype=float32),
#  array([563.], dtype=float32),
#  array([490.], dtype=float32),
#  array([513.], dtype=float32),
#  array([480.], dtype=float32),
#  array([489.], dtype=float32),
#  array([453.], dtype=float32),
#  array([502.], dtype=float32),
#  array([514.], dtype=float32),
#  array([493.], dtype=float32),
#  array([515.], dtype=float32),
#  array([465.], dtype=float32),
#  array([518.], dtype=float32),
#  array([455.], dtype=float32),
#  array([361.00003], dtype=float32),
#  array([454.], dtype=float32),
#  array([462.], dtype=float32),
#  array([510.], dtype=float32),
#  array([519.], dtype=float32),
#  array([537.], dtype=float32),
#  array([503.00003], dtype=float32),
#  array([439.], dtype=float32),
#  array([418.], dtype=float32),
#  array([419.], dtype=float32),
#  array([439.], dtype=float32),
#  array([401.], dtype=float32),
#  array([442.], dtype=float32),
#  array([425.], dtype=float32),
#  array([374.], dtype=float32),
#  array([454.], dtype=float32),
#  array([410.], dtype=float32),
#  array([382.], dtype=float32),
#  array([397.], dtype=float32),
#  array([413.], dtype=float32),
#  array([393.], dtype=float32),
#  array([377.], dtype=float32),
#  array([439.], dtype=float32),
#  array([416.], dtype=float32),
#  array([427.], dtype=float32),
#  array([466.], dtype=float32),
#  array([462.], dtype=float32),
#  array([428.], dtype=float32),
#  array([380.], dtype=float32),
#  array([427.], dtype=float32),
#  array([479.], dtype=float32),
#  array([424.99997], dtype=float32),
#  array([347.], dtype=float32),
#  array([400.], dtype=float32),
#  array([387.], dtype=float32),
#  array([315.], dtype=float32),
#  array([364.], dtype=float32),
#  array([366.], dtype=float32),
#  array([346.], dtype=float32),
#  array([357.], dtype=float32),
#  array([351.], dtype=float32),
#  array([317.], dtype=float32),
#  array([315.], dtype=float32),
#  array([307.], dtype=float32),
#  array([317.], dtype=float32),
#  array([289.], dtype=float32),
#  array([282.], dtype=float32),
#  array([229.], dtype=float32),
#  array([280.], dtype=float32),
#  array([263.], dtype=float32),
#  array([271.], dtype=float32),
#  array([240.], dtype=float32),
#  array([243.99998], dtype=float32),
#  array([234.99998], dtype=float32),
#  array([206.], dtype=float32),
#  array([179.], dtype=float32),
#  array([184.99997], dtype=float32),
#  array([234.], dtype=float32),
#  array([269.], dtype=float32),
#  array([200.], dtype=float32)]

# %%
# 计算RMSE
rmse = sqrt(mean_squared_error(mean_actual_test, mean_pre_test))
print('Test RMSE: %.7f' % rmse)
print('Test MAE: %.7f' % mean_absolute_error(mean_actual_test, mean_pre_test))
print('Test R2: %.7f' % r2_score(mean_actual_test, mean_pre_test))
# Out:
# Test RMSE: 20.1651822
# Test MAE: 16.5569462
# Test R2: 0.9847320

# %%
# 测试集
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['font.sans-serif']=['Simhei']  #解决画图中文不显示问题
plt.figure(figsize=(6,4),dpi=600)
x=range(1, len(mean_pre_test) + 1)
plt.xticks(x[::50])
plt.tick_params(labelsize=10)  #改变刻度字体大小
plt.plot(x, mean_actual_test, linestyle="--",color='g',linewidth=1, label='Acture')
plt.plot(x, mean_pre_test,  color='red',linestyle="--",linewidth=1,label='EMD-HHO-DELM')
plt.rcParams.update({'font.size': 10})  #改变图例里面的字体大小
plt.legend(loc='upper right')
plt.xlabel("样本点",fontsize=10)
plt.ylabel("值",fontsize=10)
# plt.xlim(xmin=600,xmax=700)  #显示600-1000的值   局部放大有利于观察
# plt.savefig('台湾VMD-LSTM震级预测结果图.png')
plt.show()

# %%
# #保存预测结果
savemat('结果/emd-delm_result.mat',{'true':mean_actual_test,'pred':mean_pre_test})
