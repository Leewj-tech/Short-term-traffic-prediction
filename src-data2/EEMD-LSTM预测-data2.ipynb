# %% [markdown]
# ### 运行前先装一个PyEMD库     是pip install pyemd   还是pip install PyEMD ，pip install EMD-signal  还试着装哪个成功

# %%
# 调用相关库
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import pandas as pd
from math import sqrt
from numpy import concatenate
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from scipy.io import savemat,loadmat
from keras.callbacks import LearningRateScheduler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from PyEMD import EMD,EEMD, Visualisation
from pandas import DataFrame
from pandas import concat
import keras.backend as K
import numpy
import os

# %%
# 转换成监督数据，将每个特征转换成21列数据，20->1，20组预测一组
def series_to_supervised(data, n_in=20, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]  #计算特征的数量
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    # 将20组输入数据依次向下移动20,19,...3,2,1行，将数据加入cols列表（技巧：(n_in, 0, -1)中的-1指倒序循环，步长为1）
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    # 将一组输出数据加入cols列表（技巧：其中i=0）
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # cols列表(list)中现在有21块经过下移后的数据(即：df(-20),df(-19),...df(-2),df(-1),df)，将四块数据按列 并排合并
    agg = pd.concat(cols, axis=1)
    # 给合并后的数据添加列名
    agg.columns = names
    # print(agg)
    # 删除NaN值列
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
dataset = pd.read_excel("816480.xlsx")
fratures_Corrected_irradiance = [
    'Flow (Veh/5 Minutes)'
]
values = dataset[fratures_Corrected_irradiance].values
n_features=1 #特征数量

# %%
values = values.astype('float32')
close = values

# %%
close=close.reshape(-1,1)
close.shape
# Out:
# (1440, 1)

# %%
eemd = EEMD()
eemd.noise_seed(555)
eemd.eemd(close.reshape(-1))
imfs_close, res_close = eemd.get_imfs_and_residue()

t = np.arange(0, 1440, 1)
vis = Visualisation()
vis.plot_imfs(imfs=imfs_close, residue=res_close, t=t, include_residue=True)
# vis.plot_instant_freq(t, imfs=imfs)
vis.show()

# %%
def implement_lstm(train_X, train_y):
    inputs=Input(shape=(train_X.shape[1], train_X.shape[2]))
    lstm=LSTM(32, activation='selu',return_sequences=False)(inputs)
    outputs = Dense(1)(lstm)
    model = Model(inputs=inputs, outputs=outputs)
#     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.02),loss='mse')
    model.compile(loss='mse',optimizer='Adam')
    model.summary()#展示模型结构
    return model

# %%
svr = []
prediction_test = []
actual_test = []

i = 1
svr = []
prediction_test = []
actual_test = []

for imf in imfs_close:
    imf=imf.reshape(-1,1)
    imf=pd.DataFrame(imf)
    data_=imf.values
    data_ = data_.astype('float32')
    # 标准化
    scaler =StandardScaler()
    scaled = scaler.fit_transform(data_)
    
    # 构建成监督学习问题
    n_in=3
    n_out=1
    n_vars=1
# 构建成监督学习问题
    reframed = series_to_supervised(scaled, n_in, n_out)  # 预测时间步长为15 ，输出时间步1  ，即由t-15,t-14,....t-1预测t
    values_ = reframed.values 
    ratio=0.8 #训练集和测试集的划分比例
    N=int(len(values_) *ratio)
    train = values_[:N, :]
    test = values_[N:, :]
    # 把数据分为输入和输出
    train_X, train_y = train[:, :n_in*n_vars], train[:, n_in*n_vars:]
    test_X, test_y = test[:, :n_in*n_vars], test[:, n_in*n_vars:]
    # 把输入重塑成3D格式 [样例，时间步， 特征]
    train_X = train_X.reshape((train_X.shape[0], n_in, n_vars))
    test_X = test_X.reshape((test_X.shape[0],n_in, n_vars))
    
 


    tmp = implement_lstm(train_X, train_y)
    history = tmp.fit(train_X, train_y, epochs=60, batch_size=30, validation_data=(test_X, test_y), verbose=2,
                        shuffle=False)
    svr.append(tmp)
    
    
    # 作出预测
    yhat = tmp.predict(test_X)
    # 反向缩放预测值  测试集
    yhat = np.repeat(yhat,n_in*n_vars+n_out, axis=-1)
    inv_yhat=scaler.inverse_transform(np.reshape(yhat,(len(yhat),n_in*n_vars+n_out)))[:,0]
    prediction_test.append(inv_yhat)
    # 反向缩放实际值  测试集
    y = np.repeat(test_y,n_in*n_vars+n_out, axis=-1)
    inv_y=scaler.inverse_transform(np.reshape(y,(len(test_y),n_in*n_vars+n_out)))[:,0]
    actual_test.append(inv_y)

    





#####残差
imf=res_close.reshape(-1,1)
imf=pd.DataFrame(imf)
data_=imf.values
data_ = data_.astype('float32')
# 标准化
scaler =StandardScaler()
scaled = scaler.fit_transform(data_)
    
# 构建成监督学习问题
n_in=3
n_out=1
n_vars=1
# 构建成监督学习问题
reframed = series_to_supervised(scaled, n_in, n_out)  # 预测时间步长为15 ，输出时间步1  ，即由t-15,t-14,....t-1预测t
values_ = reframed.values 
ratio=0.8 #训练集和测试集的划分比例
N=int(len(values_) *ratio)
train = values_[:N, :]
test = values_[N:, :]
# 把数据分为输入和输出
train_X, train_y = train[:, :n_in*n_vars], train[:, n_in*n_vars:]
test_X, test_y = test[:, :n_in*n_vars], test[:, n_in*n_vars:]
# 把输入重塑成3D格式 [样例，时间步， 特征]
train_X = train_X.reshape((train_X.shape[0], n_in, n_vars))
test_X = test_X.reshape((test_X.shape[0],n_in, n_vars))
    



tmp = implement_lstm(train_X, train_y)
history = tmp.fit(train_X, train_y, epochs=60, batch_size=30,validation_data=(test_X, test_y), verbose=2,
                        shuffle=False)
svr.append(tmp)
    

    
    
    
# 作出预测
yhat = tmp.predict(test_X)
# 反向缩放预测值  测试集
yhat = np.repeat(yhat,n_in*n_vars+1, axis=-1)
inv_yhat=scaler.inverse_transform(np.reshape(yhat,(len(yhat),n_in*n_vars+1)))[:,0]
prediction_test.append(inv_yhat)
# 反向缩放实际值  测试集
y = np.repeat(test_y,n_in*n_vars+1, axis=-1)
inv_y=scaler.inverse_transform(np.reshape(y,(len(test_y),n_in*n_vars+1)))[:,0]
actual_test.append(inv_y)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3, 1)]            0
#
#  lstm (LSTM)                 (None, 32)                4352
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 39/39 - 1s - loss: 0.8931 - val_loss: 0.9769 - 891ms/epoch - 23ms/step
# Epoch 2/60
# 39/39 - 0s - loss: 0.7437 - val_loss: 0.8249 - 56ms/epoch - 1ms/step
# Epoch 3/60
# 39/39 - 0s - loss: 0.6364 - val_loss: 0.7148 - 59ms/epoch - 2ms/step
# Epoch 4/60
# 39/39 - 0s - loss: 0.5740 - val_loss: 0.6633 - 58ms/epoch - 1ms/step
# Epoch 5/60
# 39/39 - 0s - loss: 0.5544 - val_loss: 0.6461 - 60ms/epoch - 2ms/step
# Epoch 6/60
# 39/39 - 0s - loss: 0.5497 - val_loss: 0.6387 - 56ms/epoch - 1ms/step
# Epoch 7/60
# 39/39 - 0s - loss: 0.5471 - val_loss: 0.6339 - 56ms/epoch - 1ms/step
# Epoch 8/60
# 39/39 - 0s - loss: 0.5449 - val_loss: 0.6310 - 58ms/epoch - 1ms/step
# Epoch 9/60
# 39/39 - 0s - loss: 0.5430 - val_loss: 0.6287 - 55ms/epoch - 1ms/step
# Epoch 10/60
# 39/39 - 0s - loss: 0.5412 - val_loss: 0.6265 - 57ms/epoch - 1ms/step
# Epoch 11/60
# 39/39 - 0s - loss: 0.5394 - val_loss: 0.6248 - 52ms/epoch - 1ms/step
# Epoch 12/60
# 39/39 - 0s - loss: 0.5376 - val_loss: 0.6232 - 53ms/epoch - 1ms/step
# Epoch 13/60
# 39/39 - 0s - loss: 0.5358 - val_loss: 0.6219 - 57ms/epoch - 1ms/step
# Epoch 14/60
# 39/39 - 0s - loss: 0.5342 - val_loss: 0.6209 - 55ms/epoch - 1ms/step
# Epoch 15/60
# 39/39 - 0s - loss: 0.5329 - val_loss: 0.6201 - 59ms/epoch - 2ms/step
# Epoch 16/60
# 39/39 - 0s - loss: 0.5315 - val_loss: 0.6194 - 57ms/epoch - 1ms/step
# Epoch 17/60
# 39/39 - 0s - loss: 0.5302 - val_loss: 0.6188 - 55ms/epoch - 1ms/step
# Epoch 18/60
# 39/39 - 0s - loss: 0.5289 - val_loss: 0.6181 - 60ms/epoch - 2ms/step
# Epoch 19/60
# 39/39 - 0s - loss: 0.5276 - val_loss: 0.6177 - 55ms/epoch - 1ms/step
# Epoch 20/60
# 39/39 - 0s - loss: 0.5264 - val_loss: 0.6170 - 57ms/epoch - 1ms/step
# Epoch 21/60
# 39/39 - 0s - loss: 0.5252 - val_loss: 0.6165 - 56ms/epoch - 1ms/step
# Epoch 22/60
# 39/39 - 0s - loss: 0.5240 - val_loss: 0.6161 - 57ms/epoch - 1ms/step
# Epoch 23/60
# 39/39 - 0s - loss: 0.5230 - val_loss: 0.6157 - 59ms/epoch - 2ms/step
# Epoch 24/60
# 39/39 - 0s - loss: 0.5220 - val_loss: 0.6156 - 59ms/epoch - 2ms/step
# Epoch 25/60
# 39/39 - 0s - loss: 0.5210 - val_loss: 0.6154 - 64ms/epoch - 2ms/step
# Epoch 26/60
# 39/39 - 0s - loss: 0.5200 - val_loss: 0.6153 - 58ms/epoch - 1ms/step
# Epoch 27/60
# 39/39 - 0s - loss: 0.5191 - val_loss: 0.6155 - 53ms/epoch - 1ms/step
# Epoch 28/60
# 39/39 - 0s - loss: 0.5181 - val_loss: 0.6156 - 57ms/epoch - 1ms/step
# Epoch 29/60
# 39/39 - 0s - loss: 0.5171 - val_loss: 0.6155 - 54ms/epoch - 1ms/step
# Epoch 30/60
# 39/39 - 0s - loss: 0.5162 - val_loss: 0.6156 - 56ms/epoch - 1ms/step
# Epoch 31/60
# 39/39 - 0s - loss: 0.5154 - val_loss: 0.6156 - 59ms/epoch - 2ms/step
# Epoch 32/60
# 39/39 - 0s - loss: 0.5145 - val_loss: 0.6156 - 54ms/epoch - 1ms/step
# Epoch 33/60
# 39/39 - 0s - loss: 0.5137 - val_loss: 0.6156 - 51ms/epoch - 1ms/step
# Epoch 34/60
# 39/39 - 0s - loss: 0.5130 - val_loss: 0.6157 - 53ms/epoch - 1ms/step
# Epoch 35/60
# 39/39 - 0s - loss: 0.5122 - val_loss: 0.6158 - 57ms/epoch - 1ms/step
# Epoch 36/60
# 39/39 - 0s - loss: 0.5115 - val_loss: 0.6160 - 61ms/epoch - 2ms/step
# Epoch 37/60
# 39/39 - 0s - loss: 0.5108 - val_loss: 0.6161 - 68ms/epoch - 2ms/step
# Epoch 38/60
# 39/39 - 0s - loss: 0.5102 - val_loss: 0.6165 - 63ms/epoch - 2ms/step
# Epoch 39/60
# 39/39 - 0s - loss: 0.5097 - val_loss: 0.6167 - 58ms/epoch - 1ms/step
# Epoch 40/60
# 39/39 - 0s - loss: 0.5092 - val_loss: 0.6170 - 53ms/epoch - 1ms/step
# Epoch 41/60
# 39/39 - 0s - loss: 0.5088 - val_loss: 0.6173 - 53ms/epoch - 1ms/step
# Epoch 42/60
# 39/39 - 0s - loss: 0.5083 - val_loss: 0.6175 - 49ms/epoch - 1ms/step
# Epoch 43/60
# 39/39 - 0s - loss: 0.5079 - val_loss: 0.6179 - 55ms/epoch - 1ms/step
# Epoch 44/60
# 39/39 - 0s - loss: 0
ms/epoch - 2ms/step
# Epoch 18/60
# 39/39 - 0s - loss: 0.0803 - val_loss: 0.1021 - 53ms/epoch - 1ms/step
# Epoch 19/60
# 39/39 - 0s - loss: 0.0802 - val_loss: 0.1015 - 54ms/epoch - 1ms/step
# Epoch 20/60
# 39/39 - 0s - loss: 0.0802 - val_loss: 0.1010 - 53ms/epoch - 1ms/step
# Epoch 21/60
# 39/39 - 0s - loss: 0.0802 - val_loss: 0.1005 - 56ms/epoch - 1ms/step
# Epoch 22/60
# 39/39 - 0s - loss: 0.0802 - val_loss: 0.1001 - 55ms/epoch - 1ms/step
# Epoch 23/60
# 39/39 - 0s - loss: 0.0802 - val_loss: 0.0998 - 55ms/epoch - 1ms/step
# Epoch 24/60
# 39/39 - 0s - loss: 0.0802 - val_loss: 0.0995 - 54ms/epoch - 1ms/step
# Epoch 25/60
# 39/39 - 0s - loss: 0.0802 - val_loss: 0.0992 - 54ms/epoch - 1ms/step
# Epoch 26/60
# 39/39 - 0s - loss: 0.0802 - val_loss: 0.0990 - 58ms/epoch - 1ms/step
# Epoch 27/60
# 39/39 - 0s - loss: 0.0802 - val_loss: 0.0988 - 61ms/epoch - 2ms/step
# Epoch 28/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0986 - 67ms/epoch - 2ms/step
# Epoch 29/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0983 - 58ms/epoch - 1ms/step
# Epoch 30/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0981 - 60ms/epoch - 2ms/step
# Epoch 31/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0980 - 65ms/epoch - 2ms/step
# Epoch 32/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0978 - 56ms/epoch - 1ms/step
# Epoch 33/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0977 - 59ms/epoch - 2ms/step
# Epoch 34/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0976 - 56ms/epoch - 1ms/step
# Epoch 35/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0975 - 58ms/epoch - 1ms/step
# Epoch 36/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0974 - 54ms/epoch - 1ms/step
# Epoch 37/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0974 - 53ms/epoch - 1ms/step
# Epoch 38/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0973 - 54ms/epoch - 1ms/step
# Epoch 39/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0973 - 53ms/epoch - 1ms/step
# Epoch 40/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0973 - 56ms/epoch - 1ms/step
# Epoch 41/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0972 - 58ms/epoch - 1ms/step
# Epoch 42/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0972 - 58ms/epoch - 1ms/step
# Epoch 43/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0972 - 60ms/epoch - 2ms/step
# Epoch 44/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0972 - 57ms/epoch - 1ms/step
# Epoch 45/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0972 - 55ms/epoch - 1ms/step
# Epoch 46/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0972 - 58ms/epoch - 1ms/step
# Epoch 47/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0971 - 58ms/epoch - 1ms/step
# Epoch 48/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0971 - 57ms/epoch - 1ms/step
# Epoch 49/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0971 - 58ms/epoch - 1ms/step
# Epoch 50/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0971 - 57ms/epoch - 1ms/step
# Epoch 51/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0971 - 56ms/epoch - 1ms/step
# Epoch 52/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0971 - 57ms/epoch - 1ms/step
# Epoch 53/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0971 - 58ms/epoch - 1ms/step
# Epoch 54/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0971 - 52ms/epoch - 1ms/step
# Epoch 55/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0971 - 57ms/epoch - 1ms/step
# Epoch 56/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0971 - 55ms/epoch - 1ms/step
# Epoch 57/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0972 - 54ms/epoch - 1ms/step
# Epoch 58/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0972 - 61ms/epoch - 2ms/step
# Epoch 59/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0972 - 59ms/epoch - 2ms/step
# Epoch 60/60
# 39/39 - 0s - loss: 0.0801 - val_loss: 0.0972 - 57ms/epoch - 1ms/step

# %%
mean_pre_test = []                    

for i in range(0,len(prediction_test[0])):
    sum = 0
    for j in range(0,len(prediction_test)):
        sum = sum + prediction_test[j][i]
    
#     mean = sum/len(prediction_test) 
    mean_pre_test.append(sum)
        
mean_pre_test
# Out:
# [114.6373405456543,
#  104.69036293029785,
#  120.31575274467468,
#  173.01907861232758,
#  147.26018238067627,
#  116.34859132766724,
#  111.317063331604,
#  125.06345081329346,
#  142.94966793060303,
#  131.05592930316925,
#  95.6109961271286,
#  112.72344434261322,
#  97.7421087026596,
#  101.4763913154602,
#  89.88251399993896,
#  108.70606744289398,
#  106.99599561095238,
#  87.86078748106956,
#  89.09616079926491,
#  75.71923267841339,
#  75.68184769153595,
#  78.98525321483612,
#  83.56798982620239,
#  69.70042824745178,
#  83.2409895658493,
#  81.60462857689708,
#  83.71008557081223,
#  63.073715031147,
#  63.54542690515518,
#  65.68379700183868,
#  72.52458947896957,
#  78.31525433063507,
#  65.14554834365845,
#  58.363336093723774,
#  67.79720836877823,
#  62.6753876209259,
#  48.815081179142,
#  52.601553320884705,
#  58.081716284155846,
#  60.39602020382881,
#  72.11793851852417,
#  70.15515261888504,
#  86.8007804453373,
#  97.96578240394592,
#  101.5514645576477,
#  112.4084238409996,
#  117.66904640197754,
#  97.67177772521973,
#  75.97050642967224,
#  91.18544054031372,
#  106.24485683441162,
#  104.194659948349,
#  88.58236503601074,
#  84.85868740081787,
#  137.68298196792603,
#  144.77917003631592,
#  168.16327291727066,
#  181.42775177955627,
#  185.07683563232422,
#  142.66488933563232,
#  140.23411965370178,
#  137.80946350097656,
#  175.3941102027893,
#  197.23504376411438,
#  196.3267987370491,
#  192.99809408187866,
#  238.18446707725525,
#  269.48954153060913,
#  334.0356149673462,
#  356.12687969207764,
#  332.21656799316406,
#  300.0177478790283,
#  276.49678218364716,
#  277.33676624298096,
#  283.16508162021637,
#  301.67364640708547,
#  308.3860881328583,
#  303.56419563293457,
#  323.11386585235596,
#  370.69962882995605,
#  427.5219883918762,
#  452.14798974990845,
#  448.5112247467041,
#  411.37429571151733,
#  407.37601840496063,
#  401.1669088602066,
#  443.00948429107666,
#  465.77019679546356,
#  453.1980924606323,
#  421.6488857269287,
#  464.60524147748947,
#  513.9166526794434,
#  564.222825050354,
#  509.9640884399414,
#  503.3504238128662,
#  525.996375977993,
#  488.69153559207916,
#  444.7948594093323,
#  432.64590883255005,
#  440.3923625946045,
#  446.20479822158813,
#  415.869131565094,
#  438.51122909784317,
#  409.07540822029114,
#  389.6049744486809,
#  445.51671785116196,
#  415.4341654777527,
#  386.5354903936386,
#  402.59639048576355,
#  421.610841691494,
#  405.7987911105156,
#  389.7019658088684,
#  427.5202946662903,
#  427.72995924949646,
#  441.65446734428406,
#  460.9276051521301,
#  447.629584684968,
#  408.5997266769409,
#  408.5339231491089,
#  461.5454981327057,
#  466.731764793396,
#  407.87174701690674,
#  368.1370780467987,
#  401.9485409259796,
#  375.739261507988,
#  343.4665468931198,
#  367.7317895889282,
#  369.56466913223267,
#  361.62242686748505,
#  356.57604549080133,
#  347.8177633881569,
#  326.8689556121826,
#  325.25736859440804,
#  322.6220083013177,
#  320.2669785581529,
#  294.7540843486786,
#  282.1176607608795,
#  249.35232782363892,
#  280.40074396133423,
#  277.0367807149887,
#  267.1952095925808,
#  240.04855608940125,
#  257.7446728348732,
#  245.73970699310303,
#  219.32815742492676,
#  193.3144302368164,
#  214.09167003631592,
#  243.3869743347168,
#  246.35138416290283,
#  192.65903186798096]

# %%
mean_actual_test = []

for i in range(0,len(actual_test[0])):
    sum = 0
    for j in range(0,len(actual_test)):
        sum = sum + actual_test[j][i]
    
#     mean = sum/len(actual_test)
    mean_actual_test.append(sum)
        
mean_actual_test
# Out:
# [113.99999392032623,
#  104.99999511241913,
#  91.00000524520874,
#  175.99999296665192,
#  141.00000405311584,
#  110.99999868869781,
#  107.99997663497925,
#  110.99998569488525,
#  122.00000166893005,
#  136.00001978874207,
#  89.0000057220459,
#  105.00003123283386,
#  83.9999977350235,
#  88.9999989271164,
#  79.00000098720193,
#  102.00000283122063,
#  106.99997529387474,
#  76.00000077486038,
#  84.99998590350151,
#  71.00002828240395,
#  78.00000631809235,
#  76.00002793967724,
#  84.00001254677773,
#  56.99998164176941,
#  85.00000202655792,
#  70.99999630451202,
#  82.99999445676804,
#  61.000028133392334,
#  61.00001272559166,
#  65.00000095367432,
#  67.00002527236938,
#  82.99999761581421,
#  69.99999617040157,
#  53.00000351667404,
#  71.99998873472214,
#  71.0000002682209,
#  52.000009655952454,
#  58.99999243021011,
#  56.99999749660492,
#  56.99999475479126,
#  78.00001692771912,
#  75.00002789497375,
#  85.00000977516174,
#  109.00002813339233,
#  105.999990940094,
#  118.99999690055847,
#  131.00000858306885,
#  111.99997808039188,
#  81.00002908706665,
#  86.99999523162842,
#  106.00000476837158,
#  103.99998128414154,
#  112.99997043609619,
#  87.0000228881836,
#  166.0000286102295,
#  152.00001430511475,
#  184.99997901916504,
#  200.00001108646393,
#  202.99999475479126,
#  150.0000183582306,
#  154.00000667572021,
#  131.00000762939453,
#  161.99998426437378,
#  209.00001269578934,
#  228.00002132356167,
#  206.99999117851257,
#  247.99998784065247,
#  261.0000099390745,
#  333.9999903142452,
#  388.9999952316284,
#  476.00000846385956,
#  438.9999785423279,
#  489.00001311302185,
#  519.9999895095825,
#  469.0000102519989,
#  479.99999821186066,
#  497.0000246465206,
#  450.99999755620956,
#  562.9999988079071,
#  490.00000500679016,
#  513.0000157356262,
#  479.9999752044678,
#  488.9999940395355,
#  452.9999816417694,
#  502.00000607967377,
#  514.0000102519989,
#  493.0000017993152,
#  514.9999852180481,
#  464.99998235702515,
#  518.0000171661377,
#  454.9999957084656,
#  361.0000066757202,
#  454.000022649765,
#  461.9999905228615,
#  509.99999845027924,
#  519.0000019073486,
#  537.0000137835741,
#  503.00000190734863,
#  438.9999942779541,
#  417.99997568130493,
#  418.99999140203,
#  438.9999928474426,
#  400.9999723434448,
#  441.9999885559082,
#  424.99999022483826,
#  374.00001448765397,
#  453.9999912381172,
#  410.00002533197403,
#  381.9999849796295,
#  397.00000286102295,
#  413.0000047683716,
#  393.0000034123659,
#  377.0000057220459,
#  439.0000070333481,
#  415.999981880188,
#  426.9999942779541,
#  465.99998569488525,
#  461.99998980760574,
#  427.9999873638153,
#  379.9999771118164,
#  426.9999889731407,
#  478.99999237060547,
#  424.99999833106995,
#  347.0000295639038,
#  399.9999841451645,
#  387.00000393390656,
#  314.999990940094,
#  363.9999942779541,
#  366.0000171661377,
#  346.0000170469284,
#  357.00001645088196,
#  350.99999928474426,
#  317.00000381469727,
#  314.99998170137405,
#  306.99997639656067,
#  317.00001195818186,
#  289.0000088214874,
#  282.0000033378601,
#  228.99999284744263,
#  279.9999985694885,
#  263.00000393390656,
#  270.99997913837433,
#  239.99999225139618,
#  244.00001001358032,
#  235.00001829862595,
#  206.0000123977661,
#  179.0000238418579,
#  184.99997806549072,
#  233.99998664855957,
#  269.00000858306885,
#  199.99999809265137]

# %%
# 计算RMSE
rmse = sqrt(mean_squared_error(mean_actual_test, mean_pre_test))
print('Test RMSE: %.7f' % rmse)
print('Test MAE: %.7f' % mean_absolute_error(mean_actual_test, mean_pre_test))
print('Test R2: %.7f' % r2_score(mean_actual_test, mean_pre_test))
# Out:
# Test RMSE: 14.2514219
# Test MAE: 11.3340260
# Test R2: 0.9923740

# %%
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['font.sans-serif']=['Simhei']  #解决画图中文不显示问题
plt.figure(figsize=(6,4),dpi=600)
x=range(1, len(mean_pre_test) + 1)
plt.xticks(x[::50])
plt.tick_params(labelsize=10)  #改变刻度字体大小
plt.plot(x, mean_actual_test, linestyle="--",color='g',linewidth=1, label='Acture')
plt.plot(x, mean_pre_test,  color='red',linestyle="--",linewidth=1,label='EEMD-LSTM Predict')
plt.rcParams.update({'font.size': 10})  #改变图例里面的字体大小
plt.legend(loc='upper right')
plt.xlabel("样本点",fontsize=10)
plt.ylabel("温度",fontsize=10)
# plt.xlim(xmin=600,xmax=700)  #显示600-1000的值   局部放大有利于观察
# plt.savefig('台湾VMD-LSTM震级预测结果图.png')
plt.show()

# %%
#保存预测结果
savemat('结果/eemd-lstm_result.mat',{'true':mean_actual_test,'pred':mean_pre_test})
