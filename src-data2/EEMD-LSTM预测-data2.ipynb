# %% [markdown]
# ### 运行前先装一个PyEMD库     是pip install pyemd   还是pip install PyEMD ，pip install EMD-signal  还试着装哪个成功

# %%
# 调用相关库
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import pandas as pd
from math import sqrt
from numpy import concatenate
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from scipy.io import savemat,loadmat
from keras.callbacks import LearningRateScheduler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from PyEMD import EMD,EEMD, Visualisation
from pandas import DataFrame
from pandas import concat
import keras.backend as K
import numpy
import os

# %%
import tensorflow as tf
tf.__version__
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
# 转换成监督数据，将每个特征转换成21列数据，20->1，20组预测一组
def series_to_supervised(data, n_in=20, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]  #计算特征的数量
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    # 将20组输入数据依次向下移动20,19,...3,2,1行，将数据加入cols列表（技巧：(n_in, 0, -1)中的-1指倒序循环，步长为1）
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    # 将一组输出数据加入cols列表（技巧：其中i=0）
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # cols列表(list)中现在有21块经过下移后的数据(即：df(-20),df(-19),...df(-2),df(-1),df)，将四块数据按列 并排合并
    agg = pd.concat(cols, axis=1)
    # 给合并后的数据添加列名
    agg.columns = names
    # print(agg)
    # 删除NaN值列
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
dataset = pd.read_excel("816480.xlsx")
fratures_Corrected_irradiance = [
    'Flow (Veh/5 Minutes)'
]
values = dataset[fratures_Corrected_irradiance].values
n_features=1 #特征数量

# %%
values = values.astype('float32')
close = values

# %%
close=close.reshape(-1,1)
close.shape
# Out:
# (1440, 1)

# %%
eemd = EEMD()
eemd.noise_seed(555)
eemd.eemd(close.reshape(-1))
imfs_close, res_close = eemd.get_imfs_and_residue()

t = np.arange(0, 1440, 1)
vis = Visualisation()
vis.plot_imfs(imfs=imfs_close, residue=res_close, t=t, include_residue=True)
# vis.plot_instant_freq(t, imfs=imfs)
vis.show()

# %%
def implement_lstm(train_X, train_y):
    inputs=Input(shape=(train_X.shape[1], train_X.shape[2]))
    lstm=LSTM(32, activation='selu',return_sequences=False)(inputs)
    outputs = Dense(1)(lstm)
    model = Model(inputs=inputs, outputs=outputs)
#     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.02),loss='mse')
    model.compile(loss='mse',optimizer='Adam')
    model.summary()#展示模型结构
    return model

# %%
svr = []
prediction_test = []
actual_test = []

i = 1
svr = []
prediction_test = []
actual_test = []

for imf in imfs_close:
    imf=imf.reshape(-1,1)
    imf=pd.DataFrame(imf)
    data_=imf.values
    data_ = data_.astype('float32')
    # 标准化
    scaler =StandardScaler()
    scaled = scaler.fit_transform(data_)
    
    # 构建成监督学习问题
    n_in=3
    n_out=1
    n_vars=1
# 构建成监督学习问题
    reframed = series_to_supervised(scaled, n_in, n_out)  # 预测时间步长为15 ，输出时间步1  ，即由t-15,t-14,....t-1预测t
    values_ = reframed.values 
    ratio=0.8 #训练集和测试集的划分比例
    N=int(len(values_) *ratio)
    train = values_[:N, :]
    test = values_[N:, :]
    # 把数据分为输入和输出
    train_X, train_y = train[:, :n_in*n_vars], train[:, n_in*n_vars:]
    test_X, test_y = test[:, :n_in*n_vars], test[:, n_in*n_vars:]
    # 把输入重塑成3D格式 [样例，时间步， 特征]
    train_X = train_X.reshape((train_X.shape[0], n_in, n_vars))
    test_X = test_X.reshape((test_X.shape[0],n_in, n_vars))
    
 


    tmp = implement_lstm(train_X, train_y)
    history = tmp.fit(train_X, train_y, epochs=60, batch_size=30, validation_data=(test_X, test_y), verbose=2,
                        shuffle=False)
    svr.append(tmp)
    
    
    # 作出预测
    yhat = tmp.predict(test_X)
    # 反向缩放预测值  测试集
    yhat = np.repeat(yhat,n_in*n_vars+n_out, axis=-1)
    inv_yhat=scaler.inverse_transform(np.reshape(yhat,(len(yhat),n_in*n_vars+n_out)))[:,0]
    prediction_test.append(inv_yhat)
    # 反向缩放实际值  测试集
    y = np.repeat(test_y,n_in*n_vars+n_out, axis=-1)
    inv_y=scaler.inverse_transform(np.reshape(y,(len(test_y),n_in*n_vars+n_out)))[:,0]
    actual_test.append(inv_y)

    





#####残差
imf=res_close.reshape(-1,1)
imf=pd.DataFrame(imf)
data_=imf.values
data_ = data_.astype('float32')
# 标准化
scaler =StandardScaler()
scaled = scaler.fit_transform(data_)
    
# 构建成监督学习问题
n_in=3
n_out=1
n_vars=1
# 构建成监督学习问题
reframed = series_to_supervised(scaled, n_in, n_out)  # 预测时间步长为15 ，输出时间步1  ，即由t-15,t-14,....t-1预测t
values_ = reframed.values 
ratio=0.8 #训练集和测试集的划分比例
N=int(len(values_) *ratio)
train = values_[:N, :]
test = values_[N:, :]
# 把数据分为输入和输出
train_X, train_y = train[:, :n_in*n_vars], train[:, n_in*n_vars:]
test_X, test_y = test[:, :n_in*n_vars], test[:, n_in*n_vars:]
# 把输入重塑成3D格式 [样例，时间步， 特征]
train_X = train_X.reshape((train_X.shape[0], n_in, n_vars))
test_X = test_X.reshape((test_X.shape[0],n_in, n_vars))
    



tmp = implement_lstm(train_X, train_y)
history = tmp.fit(train_X, train_y, epochs=60, batch_size=30,validation_data=(test_X, test_y), verbose=2,
                        shuffle=False)
svr.append(tmp)
    

    
    
    
# 作出预测
yhat = tmp.predict(test_X)
# 反向缩放预测值  测试集
yhat = np.repeat(yhat,n_in*n_vars+1, axis=-1)
inv_yhat=scaler.inverse_transform(np.reshape(yhat,(len(yhat),n_in*n_vars+1)))[:,0]
prediction_test.append(inv_yhat)
# 反向缩放实际值  测试集
y = np.repeat(test_y,n_in*n_vars+1, axis=-1)
inv_y=scaler.inverse_transform(np.reshape(y,(len(test_y),n_in*n_vars+1)))[:,0]
actual_test.append(inv_y)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3, 1)]            0
#
#  lstm (LSTM)                 (None, 32)                4352
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 39/39 - 1s - loss: 0.8742 - val_loss: 0.9495 - 683ms/epoch - 18ms/step
# Epoch 2/60
# 39/39 - 0s - loss: 0.7146 - val_loss: 0.7900 - 61ms/epoch - 2ms/step
# Epoch 3/60
# 39/39 - 0s - loss: 0.6093 - val_loss: 0.6979 - 60ms/epoch - 2ms/step
# Epoch 4/60
# 39/39 - 0s - loss: 0.5653 - val_loss: 0.6657 - 62ms/epoch - 2ms/step
# Epoch 5/60
# 39/39 - 0s - loss: 0.5535 - val_loss: 0.6504 - 62ms/epoch - 2ms/step
# Epoch 6/60
# 39/39 - 0s - loss: 0.5480 - val_loss: 0.6397 - 60ms/epoch - 2ms/step
# Epoch 7/60
# 39/39 - 0s - loss: 0.5444 - val_loss: 0.6326 - 63ms/epoch - 2ms/step
# Epoch 8/60
# 39/39 - 0s - loss: 0.5418 - val_loss: 0.6280 - 62ms/epoch - 2ms/step
# Epoch 9/60
# 39/39 - 0s - loss: 0.5397 - val_loss: 0.6249 - 60ms/epoch - 2ms/step
# Epoch 10/60
# 39/39 - 0s - loss: 0.5377 - val_loss: 0.6224 - 61ms/epoch - 2ms/step
# Epoch 11/60
# 39/39 - 0s - loss: 0.5358 - val_loss: 0.6204 - 59ms/epoch - 2ms/step
# Epoch 12/60
# 39/39 - 0s - loss: 0.5340 - val_loss: 0.6188 - 62ms/epoch - 2ms/step
# Epoch 13/60
# 39/39 - 0s - loss: 0.5323 - val_loss: 0.6175 - 60ms/epoch - 2ms/step
# Epoch 14/60
# 39/39 - 0s - loss: 0.5306 - val_loss: 0.6161 - 63ms/epoch - 2ms/step
# Epoch 15/60
# 39/39 - 0s - loss: 0.5291 - val_loss: 0.6149 - 59ms/epoch - 2ms/step
# Epoch 16/60
# 39/39 - 0s - loss: 0.5276 - val_loss: 0.6138 - 60ms/epoch - 2ms/step
# Epoch 17/60
# 39/39 - 0s - loss: 0.5262 - val_loss: 0.6127 - 64ms/epoch - 2ms/step
# Epoch 18/60
# 39/39 - 0s - loss: 0.5248 - val_loss: 0.6114 - 61ms/epoch - 2ms/step
# Epoch 19/60
# 39/39 - 0s - loss: 0.5234 - val_loss: 0.6104 - 62ms/epoch - 2ms/step
# Epoch 20/60
# 39/39 - 0s - loss: 0.5222 - val_loss: 0.6097 - 60ms/epoch - 2ms/step
# Epoch 21/60
# 39/39 - 0s - loss: 0.5212 - val_loss: 0.6091 - 61ms/epoch - 2ms/step
# Epoch 22/60
# 39/39 - 0s - loss: 0.5202 - val_loss: 0.6086 - 61ms/epoch - 2ms/step
# Epoch 23/60
# 39/39 - 0s - loss: 0.5192 - val_loss: 0.6080 - 63ms/epoch - 2ms/step
# Epoch 24/60
# 39/39 - 0s - loss: 0.5182 - val_loss: 0.6074 - 71ms/epoch - 2ms/step
# Epoch 25/60
# 39/39 - 0s - loss: 0.5172 - val_loss: 0.6069 - 59ms/epoch - 2ms/step
# Epoch 26/60
# 39/39 - 0s - loss: 0.5162 - val_loss: 0.6064 - 61ms/epoch - 2ms/step
# Epoch 27/60
# 39/39 - 0s - loss: 0.5154 - val_loss: 0.6063 - 68ms/epoch - 2ms/step
# Epoch 28/60
# 39/39 - 0s - loss: 0.5146 - val_loss: 0.6061 - 61ms/epoch - 2ms/step
# Epoch 29/60
# 39/39 - 0s - loss: 0.5138 - val_loss: 0.6059 - 62ms/epoch - 2ms/step
# Epoch 30/60
# 39/39 - 0s - loss: 0.5131 - val_loss: 0.6056 - 61ms/epoch - 2ms/step
# Epoch 31/60
# 39/39 - 0s - loss: 0.5124 - val_loss: 0.6057 - 60ms/epoch - 2ms/step
# Epoch 32/60
# 39/39 - 0s - loss: 0.5118 - val_loss: 0.6053 - 63ms/epoch - 2ms/step
# Epoch 33/60
# 39/39 - 0s - loss: 0.5111 - val_loss: 0.6054 - 62ms/epoch - 2ms/step
# Epoch 34/60
# 39/39 - 0s - loss: 0.5106 - val_loss: 0.6052 - 60ms/epoch - 2ms/step
# Epoch 35/60
# 39/39 - 0s - loss: 0.5100 - val_loss: 0.6050 - 62ms/epoch - 2ms/step
# Epoch 36/60
# 39/39 - 0s - loss: 0.5094 - val_loss: 0.6047 - 60ms/epoch - 2ms/step
# Epoch 37/60
# 39/39 - 0s - loss: 0.5090 - val_loss: 0.6048 - 60ms/epoch - 2ms/step
# Epoch 38/60
# 39/39 - 0s - loss: 0.5084 - val_loss: 0.6046 - 62ms/epoch - 2ms/step
# Epoch 39/60
# 39/39 - 0s - loss: 0.5080 - val_loss: 0.6048 - 61ms/epoch - 2ms/step
# Epoch 40/60
# 39/39 - 0s - loss: 0.5076 - val_loss: 0.6046 - 58ms/epoch - 1ms/step
# Epoch 41/60
# 39/39 - 0s - loss: 0.5072 - val_loss: 0.6047 - 62ms/epoch - 2ms/step
# Epoch 42/60
# 39/39 - 0s - loss: 0.5067 - val_loss: 0.6047 - 62ms/epoch - 2ms/step
# Epoch 43/60
# 39/39 - 0s - loss: 0.5063 - val_loss: 0.6047 - 61ms/epoch - 2ms/step
# Epoch 44/60
# 39/39 - 0s - loss: 0.5059 - val_loss: 0.6047 - 61ms/epoch - 2ms/step
# Epoch 45/60
# 39/39 - 0s - loss: 0.5055 - val_loss: 0.6049 - 61ms/epoch - 2ms/step
# Epoch 46/60
# 39/39 - 0s - loss: 0
ms/epoch - 1ms/step
# Epoch 11/60
# 39/39 - 0s - loss: 0.0815 - val_loss: 0.1068 - 59ms/epoch - 2ms/step
# Epoch 12/60
# 39/39 - 0s - loss: 0.0814 - val_loss: 0.1048 - 59ms/epoch - 2ms/step
# Epoch 13/60
# 39/39 - 0s - loss: 0.0812 - val_loss: 0.1032 - 59ms/epoch - 2ms/step
# Epoch 14/60
# 39/39 - 0s - loss: 0.0811 - val_loss: 0.1019 - 58ms/epoch - 1ms/step
# Epoch 15/60
# 39/39 - 0s - loss: 0.0810 - val_loss: 0.1008 - 59ms/epoch - 2ms/step
# Epoch 16/60
# 39/39 - 0s - loss: 0.0809 - val_loss: 0.0999 - 60ms/epoch - 2ms/step
# Epoch 17/60
# 39/39 - 0s - loss: 0.0808 - val_loss: 0.0991 - 60ms/epoch - 2ms/step
# Epoch 18/60
# 39/39 - 0s - loss: 0.0808 - val_loss: 0.0984 - 60ms/epoch - 2ms/step
# Epoch 19/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0979 - 61ms/epoch - 2ms/step
# Epoch 20/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0974 - 60ms/epoch - 2ms/step
# Epoch 21/60
# 39/39 - 0s - loss: 0.0806 - val_loss: 0.0970 - 59ms/epoch - 2ms/step
# Epoch 22/60
# 39/39 - 0s - loss: 0.0806 - val_loss: 0.0966 - 61ms/epoch - 2ms/step
# Epoch 23/60
# 39/39 - 0s - loss: 0.0806 - val_loss: 0.0963 - 65ms/epoch - 2ms/step
# Epoch 24/60
# 39/39 - 0s - loss: 0.0806 - val_loss: 0.0960 - 62ms/epoch - 2ms/step
# Epoch 25/60
# 39/39 - 0s - loss: 0.0806 - val_loss: 0.0957 - 61ms/epoch - 2ms/step
# Epoch 26/60
# 39/39 - 0s - loss: 0.0805 - val_loss: 0.0955 - 58ms/epoch - 1ms/step
# Epoch 27/60
# 39/39 - 0s - loss: 0.0805 - val_loss: 0.0952 - 58ms/epoch - 1ms/step
# Epoch 28/60
# 39/39 - 0s - loss: 0.0805 - val_loss: 0.0951 - 60ms/epoch - 2ms/step
# Epoch 29/60
# 39/39 - 0s - loss: 0.0805 - val_loss: 0.0950 - 61ms/epoch - 2ms/step
# Epoch 30/60
# 39/39 - 0s - loss: 0.0805 - val_loss: 0.0949 - 63ms/epoch - 2ms/step
# Epoch 31/60
# 39/39 - 0s - loss: 0.0805 - val_loss: 0.0948 - 61ms/epoch - 2ms/step
# Epoch 32/60
# 39/39 - 0s - loss: 0.0805 - val_loss: 0.0947 - 60ms/epoch - 2ms/step
# Epoch 33/60
# 39/39 - 0s - loss: 0.0805 - val_loss: 0.0946 - 61ms/epoch - 2ms/step
# Epoch 34/60
# 39/39 - 0s - loss: 0.0805 - val_loss: 0.0945 - 60ms/epoch - 2ms/step
# Epoch 35/60
# 39/39 - 0s - loss: 0.0805 - val_loss: 0.0945 - 62ms/epoch - 2ms/step
# Epoch 36/60
# 39/39 - 0s - loss: 0.0805 - val_loss: 0.0944 - 60ms/epoch - 2ms/step
# Epoch 37/60
# 39/39 - 0s - loss: 0.0805 - val_loss: 0.0944 - 68ms/epoch - 2ms/step
# Epoch 38/60
# 39/39 - 0s - loss: 0.0806 - val_loss: 0.0944 - 59ms/epoch - 2ms/step
# Epoch 39/60
# 39/39 - 0s - loss: 0.0806 - val_loss: 0.0943 - 62ms/epoch - 2ms/step
# Epoch 40/60
# 39/39 - 0s - loss: 0.0806 - val_loss: 0.0943 - 63ms/epoch - 2ms/step
# Epoch 41/60
# 39/39 - 0s - loss: 0.0806 - val_loss: 0.0943 - 61ms/epoch - 2ms/step
# Epoch 42/60
# 39/39 - 0s - loss: 0.0806 - val_loss: 0.0943 - 61ms/epoch - 2ms/step
# Epoch 43/60
# 39/39 - 0s - loss: 0.0806 - val_loss: 0.0943 - 61ms/epoch - 2ms/step
# Epoch 44/60
# 39/39 - 0s - loss: 0.0806 - val_loss: 0.0942 - 59ms/epoch - 2ms/step
# Epoch 45/60
# 39/39 - 0s - loss: 0.0806 - val_loss: 0.0942 - 62ms/epoch - 2ms/step
# Epoch 46/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0942 - 61ms/epoch - 2ms/step
# Epoch 47/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0943 - 71ms/epoch - 2ms/step
# Epoch 48/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0943 - 63ms/epoch - 2ms/step
# Epoch 49/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0943 - 61ms/epoch - 2ms/step
# Epoch 50/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0942 - 59ms/epoch - 2ms/step
# Epoch 51/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0943 - 59ms/epoch - 2ms/step
# Epoch 52/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0943 - 58ms/epoch - 1ms/step
# Epoch 53/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0943 - 66ms/epoch - 2ms/step
# Epoch 54/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0943 - 62ms/epoch - 2ms/step
# Epoch 55/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0943 - 58ms/epoch - 1ms/step
# Epoch 56/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0943 - 59ms/epoch - 2ms/step
# Epoch 57/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0943 - 60ms/epoch - 2ms/step
# Epoch 58/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0943 - 60ms/epoch - 2ms/step
# Epoch 59/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0944 - 60ms/epoch - 2ms/step
# Epoch 60/60
# 39/39 - 0s - loss: 0.0807 - val_loss: 0.0944 - 61ms/epoch - 2ms/step
# 9/9 [==============================] - 0s 751us/step

# %%
mean_pre_test = []                    

for i in range(0,len(prediction_test[0])):
    sum = 0
    for j in range(0,len(prediction_test)):
        sum = sum + prediction_test[j][i]
    
#     mean = sum/len(prediction_test) 
    mean_pre_test.append(sum)
        
mean_pre_test
# Out:
# [117.22922992706299,
#  106.84113788604736,
#  122.38760280609131,
#  175.94862139225006,
#  147.47628927230835,
#  115.4194518327713,
#  112.13179445266724,
#  126.2282133102417,
#  142.8003270626068,
#  131.6676744222641,
#  96.87846732139587,
#  113.34499287605286,
#  97.74571025371552,
#  101.9730384349823,
#  90.1106231212616,
#  108.73082608729601,
#  106.70404696464539,
#  88.03317803144455,
#  88.93254870176315,
#  74.46972906589508,
#  74.98203825950623,
#  78.9459764957428,
#  82.68071365356445,
#  69.22128188610077,
#  83.42901915311813,
#  81.04218475520611,
#  82.45088994503021,
#  62.69162178039551,
#  63.28723907470703,
#  64.55459123849869,
#  71.8349623978138,
#  77.32655489444733,
#  63.574979066848755,
#  58.0665857642889,
#  67.41817235946655,
#  61.5477077960968,
#  48.344515323638916,
#  52.36412310600281,
#  57.17549577355385,
#  59.38946530222893,
#  71.37408137321472,
#  68.71251976490021,
#  86.26796063967049,
#  96.80591851472855,
#  100.14252710342407,
#  110.98671650886536,
#  115.63861298561096,
#  95.76234817504883,
#  75.41209602355957,
#  90.20987796783447,
#  104.92257332801819,
#  103.24745738506317,
#  87.88859558105469,
#  84.48229956626892,
#  137.51082706451416,
#  143.9042739868164,
#  167.00920939445496,
#  179.49977374076843,
#  181.94995641708374,
#  140.47838187217712,
#  138.29262018203735,
#  134.62256479263306,
#  171.45869636535645,
#  193.41425967216492,
#  194.73499473929405,
#  191.98380970954895,
#  237.0831813812256,
#  267.79663598537445,
#  331.28701972961426,
#  355.47799921035767,
#  332.0533103942871,
#  299.5867862701416,
#  276.52646708488464,
#  276.58457922935486,
#  284.01201462745667,
#  302.18624944984913,
#  307.8683247566223,
#  303.8024592399597,
#  323.7891969680786,
#  370.77543091773987,
#  428.4240188598633,
#  452.8237099647522,
#  448.9051971435547,
#  412.7331314086914,
#  407.4130014181137,
#  400.7819708585739,
#  442.3887939453125,
#  510.1578001976013,
#  439.1913866996765,
#  379.5451636314392,
#  450.64763474464417,
#  474.75277894735336,
#  499.67062973976135,
#  493.7634823322296,
#  527.6486727595329,
#  489.8609848022461,
#  446.1028003692627,
#  432.86630177497864,
#  441.5450294017792,
#  446.32409477233887,
#  418.0291395187378,
#  441.115170776844,
#  411.5320830345154,
#  391.6798206567764,
#  446.2223993241787,
#  417.6996967792511,
#  387.6205235719681,
#  404.86527967453003,
#  423.4926138520241,
#  407.6494054719806,
#  391.28949451446533,
#  427.71421337127686,
#  428.2385981082916,
#  442.30053901672363,
#  461.0651898384094,
#  447.06978982686996,
#  408.8153591156006,
#  408.4739828109741,
#  460.9377086162567,
#  467.92522525787354,
#  407.1661295890808,
#  364.8880138397217,
#  404.51869463920593,
#  377.86942541599274,
#  347.59940326213837,
#  369.49587225914,
#  370.69718194007874,
#  362.70540475845337,
#  356.7575864829123,
#  347.54092544317245,
#  327.88041639328003,
#  326.4451515674591,
#  322.8954776972532,
#  320.60276278853416,
#  294.3706111907959,
#  283.0084614753723,
#  249.94152736663818,
#  281.7127094268799,
#  278.92786383628845,
#  268.7441591992974,
#  240.8887338936329,
#  257.65752613544464,
#  245.67693614959717,
#  218.8284273147583,
#  193.603346824646,
#  213.79318809509277,
#  243.19229412078857,
#  246.78760719299316,
#  191.9315996170044]

# %%
mean_actual_test = []

for i in range(0,len(actual_test[0])):
    sum = 0
    for j in range(0,len(actual_test)):
        sum = sum + actual_test[j][i]
    
#     mean = sum/len(actual_test)
    mean_actual_test.append(sum)
        
mean_actual_test
# Out:
# [113.99999392032623,
#  104.99999511241913,
#  91.00000524520874,
#  175.99999296665192,
#  141.00000405311584,
#  110.99999868869781,
#  107.99997663497925,
#  110.99998569488525,
#  122.00000166893005,
#  136.00001978874207,
#  89.0000057220459,
#  105.00003123283386,
#  83.9999977350235,
#  88.9999989271164,
#  79.00000098720193,
#  102.00000283122063,
#  106.99997529387474,
#  76.00000077486038,
#  84.99998590350151,
#  71.00002828240395,
#  78.00000631809235,
#  76.00002793967724,
#  84.00001254677773,
#  56.99998164176941,
#  85.00000202655792,
#  70.99999630451202,
#  82.99999445676804,
#  61.000028133392334,
#  61.00001272559166,
#  65.00000095367432,
#  67.00002527236938,
#  82.99999761581421,
#  69.99999617040157,
#  53.00000351667404,
#  71.99998873472214,
#  71.0000002682209,
#  52.000009655952454,
#  58.99999243021011,
#  56.99999749660492,
#  56.99999475479126,
#  78.00001692771912,
#  75.00002789497375,
#  85.00000977516174,
#  109.00002813339233,
#  105.999990940094,
#  118.99999690055847,
#  131.00000858306885,
#  111.99997808039188,
#  81.00002908706665,
#  86.99999523162842,
#  106.00000476837158,
#  103.99998128414154,
#  112.99997043609619,
#  87.0000228881836,
#  166.0000286102295,
#  152.00001430511475,
#  184.99997901916504,
#  200.00001108646393,
#  202.99999475479126,
#  150.0000183582306,
#  154.00000667572021,
#  131.00000762939453,
#  161.99998426437378,
#  209.00001269578934,
#  228.00002132356167,
#  206.99999117851257,
#  489.00000834465027,
#  505.00002098083496,
#  476.00000846385956,
#  438.9999785423279,
#  489.00001311302185,
#  519.9999895095825,
#  469.0000102519989,
#  479.99999821186066,
#  497.0000246465206,
#  450.99999755620956,
#  562.9999988079071,
#  490.00000500679016,
#  513.0000157356262,
#  479.9999752044678,
#  488.9999940395355,
#  452.9999816417694,
#  502.00000607967377,
#  514.0000102519989,
#  493.0000017993152,
#  514.9999852180481,
#  464.99998235702515,
#  518.0000171661377,
#  454.9999957084656,
#  361.0000066757202,
#  454.000022649765,
#  461.9999905228615,
#  509.99999845027924,
#  519.0000019073486,
#  537.0000137835741,
#  503.00000190734863,
#  438.9999942779541,
#  417.99997568130493,
#  418.99999140203,
#  438.9999928474426,
#  400.9999723434448,
#  441.9999885559082,
#  424.99999022483826,
#  374.00001448765397,
#  453.9999912381172,
#  410.00002533197403,
#  381.9999849796295,
#  397.00000286102295,
#  413.0000047683716,
#  393.0000034123659,
#  377.0000057220459,
#  439.0000070333481,
#  415.999981880188,
#  426.9999942779541,
#  465.99998569488525,
#  461.99998980760574,
#  427.9999873638153,
#  379.9999771118164,
#  426.9999889731407,
#  478.99999237060547,
#  424.99999833106995,
#  347.0000295639038,
#  399.9999841451645,
#  387.00000393390656,
#  314.999990940094,
#  363.9999942779541,
#  366.0000171661377,
#  346.0000170469284,
#  357.00001645088196,
#  350.99999928474426,
#  317.00000381469727,
#  314.99998170137405,
#  306.99997639656067,
#  317.00001195818186,
#  289.0000088214874,
#  282.0000033378601,
#  228.99999284744263,
#  279.9999985694885,
#  263.00000393390656,
#  270.99997913837433,
#  239.99999225139618,
#  244.00001001358032,
#  235.00001829862595,
#  206.0000123977661,
#  179.0000238418579,
#  184.99997806549072,
#  233.99998664855957,
#  269.00000858306885,
#  199.99999809265137]

# %%
# 计算RMSE
rmse = sqrt(mean_squared_error(mean_actual_test, mean_pre_test))
print('Test RMSE: %.7f' % rmse)
print('Test MAE: %.7f' % mean_absolute_error(mean_actual_test, mean_pre_test))
print('Test R2: %.7f' % r2_score(mean_actual_test, mean_pre_test))
# Out:
# Test RMSE: 14.3164103
# Test MAE: 11.3910926
# Test R2: 0.9923043

# %%
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['font.sans-serif']=['Simhei']  #解决画图中文不显示问题
plt.figure(figsize=(6,4),dpi=600)
x=range(1, len(mean_pre_test) + 1)
plt.xticks(x[::50])
plt.tick_params(labelsize=10)  #改变刻度字体大小
plt.plot(x, mean_actual_test, linestyle="--",color='g',linewidth=1, label='Acture')
plt.plot(x, mean_pre_test,  color='red',linestyle="--",linewidth=1,label='EEMD-LSTM Predict')
plt.rcParams.update({'font.size': 10})  #改变图例里面的字体大小
plt.legend(loc='upper right')
plt.xlabel("样本点",fontsize=10)
plt.ylabel("温度",fontsize=10)
# plt.xlim(xmin=600,xmax=700)  #显示600-1000的值   局部放大有利于观察
# plt.savefig('台湾VMD-LSTM震级预测结果图.png')
plt.show()

# %%
#保存预测结果
savemat('结果/eemd-lstm_result.mat',{'true':mean_actual_test,'pred':mean_pre_test})
