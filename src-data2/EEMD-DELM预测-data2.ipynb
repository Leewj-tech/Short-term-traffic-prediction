# %% [markdown]
# ### 运行前先装一个PyEMD库     是pip install pyemd pip install PyEMD，还是pip install EMD-signal 试着装哪个成功

# %%
# 调用相关库
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import pandas as pd
from math import sqrt
from numpy import concatenate
import matplotlib.pyplot as plt
import numpy as np
import random
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from PyEMD import EEMD, Visualisation
from scipy.io import savemat,loadmat
from sklearn.metrics import mean_squared_error, mean_absolute_error
from pandas import DataFrame
from pandas import concat
import numpy
import os
import copy
import scipy as spy
import math
from scipy.spatial.distance import cdist
from numpy import dot, exp

# %%
# 转换成监督数据，将每个特征转换成21列数据，20->1，20组预测一组
def series_to_supervised(data, n_in=20, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]  #计算特征的数量
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    # 将20组输入数据依次向下移动20,19,...3,2,1行，将数据加入cols列表（技巧：(n_in, 0, -1)中的-1指倒序循环，步长为1）
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    # 将一组输出数据加入cols列表（技巧：其中i=0）
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # cols列表(list)中现在有21块经过下移后的数据(即：df(-20),df(-19),...df(-2),df(-1),df)，将四块数据按列 并排合并
    agg = pd.concat(cols, axis=1)
    # 给合并后的数据添加列名
    agg.columns = names
    # print(agg)
    # 删除NaN值列
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
class DELM(object):

    def __init__(self, input_size,hidden_sizes,output_size,C,TF):
        # 初始化
        '''
            input_size:输入层节点数
            hidden_sizes:各隐含层节点数，也是各elm-ae的隐含层节点数
            output_size:输出层节点数
            C ： L2 正则化系数
            TF： 激活函数
        '''
        self._sizes = hidden_sizes
        self._l2penalty=C
        self.TF=TF 
        self.elmae=[]
        self.w=[]
        
        for i,size in enumerate(self._sizes + [output_size]):
            
            # 采样正交随机数进行网络权重初始化
            
            if input_size>=size:
                IW=spy.linalg.orth(np.random.rand(input_size,size)*2-1)
            else:
                IW=(np.random.rand(input_size,size)*2-1).T
                IW=spy.linalg.orth(IW).T
            # bias
            B=spy.linalg.orth(np.random.rand(size,1)*2-1)
            
            self.w.append(IW)
            
            if i< len(self._sizes + [output_size])-1:
                weight={'w':IW,'b':B}
                self.elmae.append(weight)
            
            input_size = size
    #无监督预训练各个ELM-AE
    def pretrain(self,X):
        self.elm_ae_weigth_list=[]#保存训练好的elmae的输出层权重 ，用于DELM初始化
        nsample=X.shape[0]
        for i in range(len(self.elmae)):
            IW=self.elmae[i]['w']
            B=self.elmae[i]['b']
            
            bias_matrix=np.tile(B,nsample).T
            
            tempH = np.dot(X,IW)+bias_matrix
            
            if self.TF=='sigmoid':
                H = 1. / (1. + np.exp(-tempH))
                
            elif self.TF=='sin':
                H=np.sin(tempH)
            # cal the output weights by least square method
            interval=(np.dot(H.T,H)+np.eye(IW.shape[1])/self._l2penalty)
            beta = np.dot(np.dot(np.linalg.pinv(interval) ,H.T),X)
            
            
            W=np.linalg.pinv(beta)
            # W = beta.T
            self.elm_ae_weigth_list.append(W)
            X=X.dot(W)
#                
    # 将训练好的elm-ae的输出层权重用于初始化delm
    def load_from_elm_aes(self):
        for i in range(len(self._sizes)):
            self.w[i] = self.elm_ae_weigth_list[i]
        
    # Training delm
    def train(self,X,Y):
        self.load_from_elm_aes()#注释掉这句 就不会采用训练好的elm-ae输出层权重对delm进行初始化
        
        
        H=[]
        input_=X
        a=len(self._sizes)
        
        for i in range(a):
            H=np.dot(input_,self.w[i])
            input_=H

        interval=np.dot(H.T,H)+np.eye(H.shape[1])/self._l2penalty
        
        beta = np.dot(np.dot(np.linalg.pinv(interval) ,H.T),Y)
        
        self.w[-1]=beta
        
    def predict(self,teX):
        H=[]
        input_=teX
        a=len(self.w)
        
        for i in range(a):
            H=np.dot(input_,self.w[i])
            input_=H
        return H

# %%
dataset = pd.read_excel("816480.xlsx")
fratures_Corrected_irradiance = [
    'Flow (Veh/5 Minutes)'
]
values = dataset[fratures_Corrected_irradiance].values
n_features=1 #特征数量

# %%
values = values.astype('float32')
close = values

# %%
close=close.reshape(-1,1)
close.shape
# Out:
# (1440, 1)

# %%
eemd = EEMD()
eemd.noise_seed(555)
eemd.eemd(close.reshape(-1))
imfs_close, res_close = eemd.get_imfs_and_residue()

t = np.arange(0, 1440, 1)
vis = Visualisation()
vis.plot_imfs(imfs=imfs_close, residue=res_close, t=t, include_residue=True)
# vis.plot_instant_freq(t, imfs=imfs)
vis.show()

# %%
prediction_test = []
actual_test = []

for imf in imfs_close:
    imf=imf.reshape(-1,1)
    imf=pd.DataFrame(imf)
    data_=imf.values
    data_ = data_.astype('float32')
    # 标准化/放缩 特征值在（0,1）之间
    scaler = StandardScaler()
    scaled = scaler.fit_transform(data_)
    
    n_in = 3
    n_out = 1
    # 构造一个20->1的监督学习型数据
    reframed = series_to_supervised(scaled, n_in=n_in, n_out=n_out)
    values=reframed.values
    
    #训练集和测试集的划分比例
    ratio=0.8 
    N=int(len(values) *ratio)
    train = values[:N, :]
    test = values[N:, :]

    # 划分输入和输出,split into input and outputs
    n_obs = n_in * n_features
    train_X, train_y = train[:, :-1], train[:, -1]
    test_X, test_y = test[:, :-1], test[:, -1]
    print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
    train_y=train_y.reshape(-1,1)
    
    
        # In[] 参数设置
    hidden_sizes = [5,5]  #几个数就是几个隐含层，n个隐含层各自的节点就是[n1;n2;n3;n4;....nn]
    input_size = train_X.shape[1] #输入层节点数
    output_size= train_y.shape[1]#输出层节点数
    C=np.inf #L2正则化系数
    TF='sin'#激活函数       "sig"
    
    # In[3]: 训练
    Net = DELM(input_size,hidden_sizes, output_size, C,TF) #construct a delm
    Net.pretrain(train_X)#train elmae
    Net.train(train_X,train_y)#train delm
    
    
    
    #预测
    yhat = Net.predict(test_X)
    yhat=yhat.reshape(-1,1)
    # 对预测结果进行反归一化
    inv_yhat = scaler.inverse_transform(yhat)
    prediction_test.append(inv_yhat)
    # 将真实列据进行反归一化
    test_y=test_y.reshape(-1,1)
    inv_y = scaler.inverse_transform(test_y)
    actual_test.append(inv_y)
    
    





#####残差
imf=res_close.reshape(-1,1)
imf=imf.reshape(-1,1)
imf=pd.DataFrame(imf)
data_=imf.values
data_ = data_.astype('float32')
#    标准化/放缩 特征值在（0,1）之间
scaler = StandardScaler()
scaled = scaler.fit_transform(data_)
    
n_in = 3
n_out = 1
# 构造一个20->1的监督学习型数据
reframed = series_to_supervised(scaled, n_in=n_in, n_out=n_out)
values=reframed.values
    
#训练集和测试集的划分比例
ratio=0.8 
N=int(len(values) *ratio)
train = values[:N, :]
test = values[N:, :]

# 划分输入和输出,split into input and outputs
n_obs = n_in * n_features
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
train_y=train_y.reshape(-1,1)
    
        # In[] 参数设置
hidden_sizes = [5,5]  #几个数就是几个隐含层，n个隐含层各自的节点就是[n1;n2;n3;n4;....nn]
input_size = train_X.shape[1] #输入层节点数
output_size= train_y.shape[1]#输出层节点数
C=np.inf #L2正则化系数
TF='sin'#激活函数       "sig"
    
# In[3]: 训练
Net = DELM(input_size,hidden_sizes, output_size, C,TF) #construct a delm
Net.pretrain(train_X)#train elmae
Net.train(train_X,train_y)#train delm
    
    
    
#预测
yhat = Net.predict(test_X)
yhat=yhat.reshape(-1,1)
# 对预测结果进行反归一化
inv_yhat = scaler.inverse_transform(yhat)
prediction_test.append(inv_yhat)
# 将真实列据进行反归一化
test_y=test_y.reshape(-1,1)
inv_y = scaler.inverse_transform(test_y)
actual_test.append(inv_y)
# Out:
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)

# %%
mean_pre_test = []                    

for i in range(0,len(prediction_test[0])):
    sum = 0
    for j in range(0,len(prediction_test)):
        sum = sum + prediction_test[j][i]

    mean_pre_test.append(sum)
        
mean_pre_test
# Out:
# [array([107.80064262]),
#  array([96.99569979]),
#  array([114.15876813]),
#  array([168.16292723]),
#  array([145.52859766]),
#  array([116.27348197]),
#  array([107.83765361]),
#  array([117.8191665]),
#  array([133.87466987]),
#  array([123.48111662]),
#  array([91.51874423]),
#  array([99.38830493]),
#  array([86.33871592]),
#  array([92.02717044]),
#  array([84.21022675]),
#  array([101.16052475]),
#  array([101.74603486]),
#  array([83.39995013]),
#  array([82.05483088]),
#  array([68.12317049]),
#  array([69.05851477]),
#  array([75.6982993]),
#  array([80.62850795]),
#  array([68.41943222]),
#  array([78.42540507]),
#  array([77.71890329]),
#  array([80.10951831]),
#  array([61.82892762]),
#  array([61.24930809]),
#  array([63.03544847]),
#  array([71.49282433]),
#  array([77.67471225]),
#  array([66.60396665]),
#  array([60.41798775]),
#  array([66.26918075]),
#  array([62.39019887]),
#  array([51.87953254]),
#  array([55.45236043]),
#  array([61.54054844]),
#  array([63.57672688]),
#  array([76.30047399]),
#  array([75.12207735]),
#  array([93.64430063]),
#  array([103.47295368]),
#  array([107.57713162]),
#  array([117.93070677]),
#  array([122.56024398]),
#  array([103.61067072]),
#  array([84.45950442]),
#  array([95.570715]),
#  array([114.65646726]),
#  array([111.54174867]),
#  array([103.48949329]),
#  array([95.09746661]),
#  array([144.52400039]),
#  array([155.84223894]),
#  array([185.85029958]),
#  array([199.85228589]),
#  array([198.17730009]),
#  array([158.04454729]),
#  array([151.63398726]),
#  array([147.72384125]),
#  array([183.86013131]),
#  array([212.41847945]),
#  array([215.72519246]),
#  array([212.92132512]),
#  array([248.07734566]),
#  array([279.72286692]),
#  array([345.40866153]),
#  array([370.79746822]),
#  array([346.03679845]),
#  array([317.02579713]),
#  array([294.3178195]),
#  array([292.39987152]),
#  array([296.14139542]),
#  array([316.26022691]),
#  array([328.99747683]),
#  array([327.4022079]),
#  array([342.43512303]),
#  array([384.74567567]),
#  array([442.3350248]),
#  array([464.8621642]),
#  array([462.95987837]),
#  array([423.23482675]),
#  array([415.47824345]),
#  array([410.85131804]),
#  array([452.04704134]),
#  array([479.12676723]),
#  array([467.84689721]),
#  array([432.13624333]),
#  array([461.2916945]),
#  array([522.12823811]),
#  array([579.55138648]),
#  array([523.36478809]),
#  array([516.56859082]),
#  array([514.91436672]),
#  array([439.80439184]),
#  array([404.97109444]),
#  array([401.51709115]),
#  array([441.75111167]),
#  array([428.3286523]),
#  array([438.19925689]),
#  array([439.42177951]),
#  array([409.71119653]),
#  array([423.32449216]),
#  array([433.730884]),
#  array([462.48198578]),
#  array([439.62056297]),
#  array([381.68511796]),
#  array([357.7959525]),
#  array([374.54549234]),
#  array([431.66855403]),
#  array([426.43097409]),
#  array([421.35685421]),
#  array([405.47862189]),
#  array([419.8803342]),
#  array([430.94628228]),
#  array([476.08915673]),
#  array([446.79647165]),
#  array([399.30234854]),
#  array([427.95644409]),
#  array([458.39513234]),
#  array([450.30857348]),
#  array([450.9067064]),
#  array([442.89038109]),
#  array([430.76309616]),
#  array([410.34416443]),
#  array([454.18546555]),
#  array([447.12261242]),
#  array([442.71867623]),
#  array([470.3297334]),
#  array([466.8819998]),
#  array([463.17604678]),
#  array([477.78052891]),
#  array([493.69765101]),
#  array([484.094955]),
#  array([494.54399065]),
#  array([473.06628934]),
#  array([463.23620691]),
#  array([472.49220764]),
#  array([474.4106349]),
#  array([496.85463844]),
#  array([535.73539937]),
#  array([538.55530624]),
#  array([523.69701228]),
#  array([532.19734839]),
#  array([504.82724112]),
#  array([515.77793599]),
#  array([525.17876092]),
#  array([519.51541045]),
#  array([544.49139505]),
#  array([540.06084063]),
#  array([554.17375312]),
#  array([547.50743695]),
#  array([537.03433415]),
#  array([543.71244762]),
#  array([561.50391234]),
#  array([590.44607834]),
#  array([571.60524693]),
#  array([563.37408765]),
#  array([559.41894633]),
#  array([541.86221523]),
#  array([539.80505381]),
#  array([520.56713518]),
#  array([544.55808115]),
#  array([568.12219327]),
#  array([549.64320107]),
#  array([515.43031803]),
#  array([539.84319049]),
#  array([559.34390463]),
#  array([540.34260576]),
#  array([501.59799799]),
#  array([511.18226174]),
#  array([544.22809676]),
#  array([562.95273998]),
#  array([532.45841108]),
#  array([511.9451816]),
#  array([492.90585164]),
#  array([511.61943183]),
#  array([507.50675717]),
#  array([541.64372589]),
#  array([550.62680457]),
#  array([527.35694121]),
#  array([511.01443153]),
#  array([507.53631434]),
#  array([521.07308947]),
#  array([537.25573903]),
#  array([552.64301583]),
#  array([507.46080728]),
#  array([505.64894711]),
#  array([489.71741922]),
#  array([526.70852534]),
#  array([491.64935241]),
#  array([487.65032817]),
#  array([500.33643244]),
#  array([510.45532017]),
#  array([525.90120222]),
#  array([513.03192053]),
#  array([484.12221322]),
#  array([499.07729168]),
#  array([527.14329229]),
#  array([512.74633345]),
#  array([461.49252317]),
#  array([483.67870924]),
#  array([498.10662582]),
#  array([502.07683624]),
#  array([491.89361772]),
#  array([455.96505132]),
#  array([451.88367277]),
#  array([489.39611397]),
#  array([506.15767906]),
#  array([477.86098662]),
#  array([479.19101579]),
#  array([469.34255685]),
#  array([469.02839752]),
#  array([540.41632334]),
#  array([522.2269829]),
#  array([507.71195453]),
#  array([473.62535668]),
#  array([489.99275843]),
#  array([463.07102446]),
#  array([488.51386001]),
#  array([502.40544975]),
#  array([504.17298943]),
#  array([503.23465407]),
#  array([491.70556115]),
#  array([507.62487965]),
#  array([433.96068299]),
#  array([380.59335891]),
#  array([430.46259163]),
#  array([463.43981448]),
#  array([499.7056588]),
#  array([501.16259618]),
#  array([520.36302538]),
#  array([487.16156425]),
#  array([443.04883224]),
#  array([428.14693303]),
#  array([436.10358875]),
#  array([439.25103003]),
#  array([417.38698347]),
#  array([434.62893133]),
#  array([403.02318451]),
#  array([388.09876471]),
#  array([432.15086086]),
#  array([407.77725174]),
#  array([391.10571012]),
#  array([400.96344543]),
#  array([419.44009308]),
#  array([399.22387201]),
#  array([387.13694417]),
#  array([419.60779619]),
#  array([423.13219146]),
#  array([440.94877912]),
#  array([458.05962129]),
#  array([440.53886686]),
#  array([403.76342228]),
#  array([396.50273831]),
#  array([451.33784715]),
#  array([462.48966945]),
#  array([399.51850809]),
#  array([359.21330771]),
#  array([390.86177978]),
#  array([364.14979031]),
#  array([332.84756319]),
#  array([351.4740233]),
#  array([356.81113671]),
#  array([350.6377774]),
#  array([348.88277137]),
#  array([337.66375114]),
#  array([318.58298675]),
#  array([315.5973794]),
#  array([313.852481]),
#  array([311.01992682]),
#  array([289.0175591]),
#  array([275.1640994]),
#  array([239.79037562]),
#  array([268.54818108]),
#  array([264.49161632]),
#  array([263.8376161]),
#  array([238.07600519]),
#  array([250.86471239]),
#  array([238.79561203]),
#  array([210.3023066]),
#  array([184.14640304]),
#  array([204.09456158]),
#  array([242.44410158]),
#  array([243.95055161]),
#  array([191.05730646])]

# %%
mean_actual_test = []

for i in range(0,len(actual_test[0])):
    sum = 0
    for j in range(0,len(actual_test)):
        sum = sum + actual_test[j][i]

    mean_actual_test.append(sum)
        
mean_actual_test
# Out:
# [array([114.], dtype=float32),
#  array([105.], dtype=float32),
#  array([91.00003], dtype=float32),
#  array([176.], dtype=float32),
#  array([141.00003], dtype=float32),
#  array([111.], dtype=float32),
#  array([107.99997], dtype=float32),
#  array([111.], dtype=float32),
#  array([122.], dtype=float32),
#  array([136.00003], dtype=float32),
#  array([89.00003], dtype=float32),
#  array([105.00003], dtype=float32),
#  array([84.], dtype=float32),
#  array([89.], dtype=float32),
#  array([79.], dtype=float32),
#  array([102.], dtype=float32),
#  array([107.], dtype=float32),
#  array([76.], dtype=float32),
#  array([84.99997], dtype=float32),
#  array([71.00003], dtype=float32),
#  array([78.], dtype=float32),
#  array([76.00003], dtype=float32),
#  array([84.00003], dtype=float32),
#  array([57.], dtype=float32),
#  array([85.], dtype=float32),
#  array([71.00003], dtype=float32),
#  array([82.99997], dtype=float32),
#  array([61.00003], dtype=float32),
#  array([61.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([83.], dtype=float32),
#  array([70.], dtype=float32),
#  array([53.], dtype=float32),
#  array([71.99997], dtype=float32),
#  array([71.], dtype=float32),
#  array([52.], dtype=float32),
#  array([59.], dtype=float32),
#  array([57.], dtype=float32),
#  array([57.], dtype=float32),
#  array([78.], dtype=float32),
#  array([75.00003], dtype=float32),
#  array([85.], dtype=float32),
#  array([109.], dtype=float32),
#  array([105.99997], dtype=float32),
#  array([119.], dtype=float32),
#  array([131.00003], dtype=float32),
#  array([112.], dtype=float32),
#  array([81.00003], dtype=float32),
#  array([87.], dtype=float32),
#  array([106.], dtype=float32),
#  array([104.], dtype=float32),
#  array([112.99997], dtype=float32),
#  array([87.00003], dtype=float32),
#  array([166.00003], dtype=float32),
#  array([152.], dtype=float32),
#  array([184.99997], dtype=float32),
#  array([200.], dtype=float32),
#  array([203.], dtype=float32),
#  array([150.], dtype=float32),
#  array([154.], dtype=float32),
#  array([131.], dtype=float32),
#  array([161.99997], dtype=float32),
#  array([209.], dtype=float32),
#  array([228.], dtype=float32),
#  array([207.], dtype=float32),
#  array([248.], dtype=float32),
#  array([261.00003], dtype=float32),
#  array([333.99997], dtype=float32),
#  array([389.00003], dtype=float32),
#  array([359.], dtype=float32),
#  array([329.99997], dtype=float32),
#  array([290.00006], dtype=float32),
#  array([270.00003], dtype=float32),
#  array([274.], dtype=float32),
#  array([299.00003], dtype=float32),
#  array([327.], dtype=float32),
#  array([330.00003], dtype=float32),
#  array([347.], dtype=float32),
#  array([376.99997], dtype=float32),
#  array([447.99997], dtype=float32),
#  array([473.99997], dtype=float32),
#  array([487.00003], dtype=float32),
#  array([422.00003], dtype=float32),
#  array([417.], dtype=float32),
#  array([378.99997], dtype=float32),
#  array([408.], dtype=float32),
#  array([470.99997], dtype=float32),
#  array([501.99997], dtype=float32),
#  array([445.99994], dtype=float32),
#  array([450.], dtype=float32),
#  array([482.99997], dtype=float32),
#  array([588.], dtype=float32),
#  array([521.], dtype=float32),
#  array([498.00003], dtype=float32),
#  array([523.], dtype=float32),
#  array([412.], dtype=float32),
#  array([388.], dtype=float32),
#  array([372.99994], dtype=float32),
#  array([444.], dtype=float32),
#  array([415.99997], dtype=float32),
#  array([433.99997], dtype=float32),
#  array([455.], dtype=float32),
#  array([398.99994], dtype=float32),
#  array([435.99997], dtype=float32),
#  array([430.], dtype=float32),
#  array([448.00003], dtype=float32),
#  array([461.00003], dtype=float32),
#  array([392.00006], dtype=float32),
#  array([354.00003], dtype=float32),
#  array([349.99997], dtype=float32),
#  array([424.00003], dtype=float32),
#  array([425.00003], dtype=float32),
#  array([433.99997], dtype=float32),
#  array([419.99997], dtype=float32),
#  array([428.00003], dtype=float32),
#  array([408.], dtype=float32),
#  array([469.99997], dtype=float32),
#  array([472.99997], dtype=float32),
#  array([392.99997], dtype=float32),
#  array([429.99997], dtype=float32),
#  array([466.99997], dtype=float32),
#  array([435.99997], dtype=float32),
#  array([451.00003], dtype=float32),
#  array([453.99997], dtype=float32),
#  array([451.00003], dtype=float32),
#  array([393.00006], dtype=float32),
#  array([476.99997], dtype=float32),
#  array([446.00003], dtype=float32),
#  array([432.99997], dtype=float32),
#  array([474.], dtype=float32),
#  array([463.99997], dtype=float32),
#  array([449.99994], dtype=float32),
#  array([479.00003], dtype=float32),
#  array([503.], dtype=float32),
#  array([475.], dtype=float32),
#  array([506.], dtype=float32),
#  array([478.00003], dtype=float32),
#  array([449.], dtype=float32),
#  array([479.], dtype=float32),
#  array([467.], dtype=float32),
#  array([474.00006], dtype=float32),
#  array([535.], dtype=float32),
#  array([546.], dtype=float32),
#  array([513.], dtype=float32),
#  array([552.9999], dtype=float32),
#  array([487.99997], dtype=float32),
#  array([506.99997], dtype=float32),
#  array([539.], dtype=float32),
#  array([512.], dtype=float32),
#  array([561.], dtype=float32),
#  array([534.], dtype=float32),
#  array([555.99994], dtype=float32),
#  array([547.], dtype=float32),
#  array([541.], dtype=float32),
#  array([541.], dtype=float32),
#  array([549.], dtype=float32),
#  array([592.], dtype=float32),
#  array([573.], dtype=float32),
#  array([565.], dtype=float32),
#  array([567.], dtype=float32),
#  array([532.], dtype=float32),
#  array([541.], dtype=float32),
#  array([519.], dtype=float32),
#  array([523.], dtype=float32),
#  array([573.], dtype=float32),
#  array([567.], dtype=float32),
#  array([506.99994], dtype=float32),
#  array([533.], dtype=float32),
#  array([556.], dtype=float32),
#  array([558.], dtype=float32),
#  array([510.], dtype=float32),
#  array([505.00003], dtype=float32),
#  array([533.], dtype=float32),
#  array([569.99994], dtype=float32),
#  array([535.], dtype=float32),
#  array([525.], dtype=float32),
#  array([478.], dtype=float32),
#  array([517.], dtype=float32),
#  array([491.99997], dtype=float32),
#  array([537.], dtype=float32),
#  array([563.], dtype=float32),
#  array([523.], dtype=float32),
#  array([509.00003], dtype=float32),
#  array([509.], dtype=float32),
#  array([515.], dtype=float32),
#  array([519.], dtype=float32),
#  array([566.], dtype=float32),
#  array([489.00003], dtype=float32),
#  array([521.], dtype=float32),
#  array([477.], dtype=float32),
#  array([532.], dtype=float32),
#  array([496.99997], dtype=float32),
#  array([483.99997], dtype=float32),
#  array([506.], dtype=float32),
#  array([493.], dtype=float32),
#  array([525.], dtype=float32),
#  array([536.], dtype=float32),
#  array([481.], dtype=float32),
#  array([481.00003], dtype=float32),
#  array([518.], dtype=float32),
#  array([526.], dtype=float32),
#  array([454.], dtype=float32),
#  array([496.99994], dtype=float32),
#  array([503.99997], dtype=float32),
#  array([489.00003], dtype=float32),
#  array([505.], dtype=float32),
#  array([476.], dtype=float32),
#  array([438.99997], dtype=float32),
#  array([489.], dtype=float32),
#  array([520.], dtype=float32),
#  array([469.00003], dtype=float32),
#  array([480.], dtype=float32),
#  array([497.00003], dtype=float32),
#  array([451.], dtype=float32),
#  array([563.], dtype=float32),
#  array([490.], dtype=float32),
#  array([513.], dtype=float32),
#  array([479.99997], dtype=float32),
#  array([489.], dtype=float32),
#  array([453.], dtype=float32),
#  array([502.], dtype=float32),
#  array([514.], dtype=float32),
#  array([493.00003], dtype=float32),
#  array([515.], dtype=float32),
#  array([464.99994], dtype=float32),
#  array([518.], dtype=float32),
#  array([455.], dtype=float32),
#  array([361.00003], dtype=float32),
#  array([454.00006], dtype=float32),
#  array([462.00003], dtype=float32),
#  array([509.99997], dtype=float32),
#  array([519.], dtype=float32),
#  array([537.], dtype=float32),
#  array([503.00003], dtype=float32),
#  array([438.99997], dtype=float32),
#  array([417.99997], dtype=float32),
#  array([418.99994], dtype=float32),
#  array([438.99997], dtype=float32),
#  array([400.99997], dtype=float32),
#  array([442.], dtype=float32),
#  array([424.99997], dtype=float32),
#  array([374.], dtype=float32),
#  array([453.99997], dtype=float32),
#  array([410.00006], dtype=float32),
#  array([382.00003], dtype=float32),
#  array([396.99997], dtype=float32),
#  array([413.], dtype=float32),
#  array([393.00003], dtype=float32),
#  array([377.], dtype=float32),
#  array([439.], dtype=float32),
#  array([415.99997], dtype=float32),
#  array([427.], dtype=float32),
#  array([466.00003], dtype=float32),
#  array([461.99997], dtype=float32),
#  array([428.00003], dtype=float32),
#  array([379.99997], dtype=float32),
#  array([427.], dtype=float32),
#  array([478.99997], dtype=float32),
#  array([424.99997], dtype=float32),
#  array([347.00003], dtype=float32),
#  array([400.], dtype=float32),
#  array([387.], dtype=float32),
#  array([315.], dtype=float32),
#  array([363.99997], dtype=float32),
#  array([366.00003], dtype=float32),
#  array([346.], dtype=float32),
#  array([357.], dtype=float32),
#  array([351.], dtype=float32),
#  array([317.], dtype=float32),
#  array([315.], dtype=float32),
#  array([307.], dtype=float32),
#  array([317.], dtype=float32),
#  array([288.99997], dtype=float32),
#  array([281.99997], dtype=float32),
#  array([229.], dtype=float32),
#  array([280.00003], dtype=float32),
#  array([262.99997], dtype=float32),
#  array([270.99997], dtype=float32),
#  array([239.99997], dtype=float32),
#  array([244.], dtype=float32),
#  array([235.00003], dtype=float32),
#  array([206.00003], dtype=float32),
#  array([179.], dtype=float32),
#  array([185.], dtype=float32),
#  array([234.], dtype=float32),
#  array([268.99997], dtype=float32),
#  array([200.00003], dtype=float32)]

# %%
# 计算RMSE
rmse = sqrt(mean_squared_error(mean_actual_test, mean_pre_test))
print('Test RMSE: %.7f' % rmse)
print('Test MAE: %.7f' % mean_absolute_error(mean_actual_test, mean_pre_test))
print('Test R2: %.7f' % r2_score(mean_actual_test, mean_pre_test))
# Out:
# Test RMSE: 12.7315697
# Test MAE: 10.0735356
# Test R2: 0.9939139

# %%
# 测试集
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['font.sans-serif']=['Simhei']  #解决画图中文不显示问题
plt.figure(figsize=(6,4),dpi=600)
x=range(1, len(mean_pre_test) + 1)
plt.xticks(x[::50])
plt.tick_params(labelsize=10)  #改变刻度字体大小
plt.plot(x, mean_actual_test, linestyle="--",color='g',linewidth=1, label='Acture')
plt.plot(x, mean_pre_test,  color='red',linestyle="--",linewidth=1,label='EMD-HHO-DELM')
plt.rcParams.update({'font.size': 10})  #改变图例里面的字体大小
plt.legend(loc='upper right')
plt.xlabel("样本点",fontsize=10)
plt.ylabel("值",fontsize=10)
# plt.xlim(xmin=600,xmax=700)  #显示600-1000的值   局部放大有利于观察
# plt.savefig('台湾VMD-LSTM震级预测结果图.png')
plt.show()

# %%
# #保存预测结果
savemat('结果/eemd-delm_result.mat',{'true':mean_actual_test,'pred':mean_pre_test})
