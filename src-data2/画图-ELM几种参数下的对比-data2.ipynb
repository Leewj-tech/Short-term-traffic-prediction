# %%
import matplotlib.pyplot as plt
from scipy.io import loadmat
import numpy as np
from math import sqrt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
def quota(inv_y, inv_yhat,name):
    rmse_ = sqrt(mean_squared_error(inv_y, inv_yhat))
    mae_=mean_absolute_error(inv_y, inv_yhat)
    r2_ = r2_score(inv_y, inv_yhat)
    print(name,'的rmse:', rmse_, ' mae:', mae_, ' R2:', r2_)

# %%
data0=loadmat('结果/delm1_result.mat')['true']
data1=loadmat('结果/delm1_result.mat')['pred']
data2=loadmat('结果/delm2_result.mat')['pred']
data3=loadmat('结果/delm3_result.mat')['pred']

# %%
print(data0.shape,data1.shape,data2.shape,data3.shape)
# Out:
# (288, 1) (288, 1) (288, 1) (288, 1)

# %%
quota(data0,data1,'DELM')
quota(data0,data2,'DELM2')
quota(data0,data3,'DELM3')
# Out:
# DELM 的rmse: 36.86150413871608  mae: 28.201273885857717  R2: 0.9489819089591184
# DELM2 的rmse: 34.780082882143994  mae: 27.037683345114644  R2: 0.9545808163288836
# DELM3 的rmse: 34.560702270559545  mae: 26.986046154989236  R2: 0.9551519859451963

# %%
# In[7] 画图
plt.figure(figsize=(12,6))
plt.plot(data0,'-',label='real')
plt.plot(data1,'-',label='DELM')
plt.plot(data2,'-',label='DELM2')
plt.plot(data3,'-',label='DELM3')
plt.xlim((0,100))
# plt.grid()
plt.legend()
plt.xlabel('Time/h',fontdict={"family":"Times New Roman"})
plt.ylabel('Congestion',fontdict={"family":"Times New Roman"})
plt.savefig('figure/DELM几种参数下预测结果图.png')
plt.show()
