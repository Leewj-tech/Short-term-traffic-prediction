# %%
import matplotlib.pyplot as plt
from scipy.io import loadmat
import numpy as np
from math import sqrt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
def quota(inv_y, inv_yhat,name):
    rmse_ = sqrt(mean_squared_error(inv_y, inv_yhat))
    mae_=mean_absolute_error(inv_y, inv_yhat)
    r2_ = r2_score(inv_y, inv_yhat)
    print(name,'的rmse:', rmse_, ' mae:', mae_, ' R2:', r2_)

# %%
data0=loadmat('结果/elm_result.mat')['true']
data1=loadmat('结果/elm_result.mat')['pred']
data2=loadmat('结果/elm2_result.mat')['pred']
data3=loadmat('结果/elm3_result.mat')['pred']

# %%
print(data0.shape,data1.shape,data2.shape,data3.shape)
# Out:
# (1000, 1) (1000, 1) (1000, 1) (1000, 1)

# %%
quota(data0,data1,'ELM')
quota(data0,data2,'ELM2')
quota(data0,data3,'ELM3')
# Out:
# ELM 的rmse: 15.394306869932715  mae: 12.297761505407097  R2: 0.0377761620075453
# ELM2 的rmse: 15.455422949714936  mae: 12.323307733909028  R2: 0.030120853686341875
# ELM3 的rmse: 15.411293140507306  mae: 12.292870135386288  R2: 0.03565153086714712

# %%
# In[7] 画图
plt.figure(figsize=(12,6))
plt.plot(data0,'-',label='real')
plt.plot(data1,'-',label='ElM')
plt.plot(data2,'-',label='ELM2')
plt.plot(data3,'-',label='ELM3')
plt.xlim((0,100))
# plt.grid()
plt.legend()
plt.xlabel('Time/h',fontdict={"family":"Times New Roman"})
plt.ylabel('Congestion',fontdict={"family":"Times New Roman"})
plt.savefig('figure/ELM几种参数下预测结果图.png')
plt.show()
