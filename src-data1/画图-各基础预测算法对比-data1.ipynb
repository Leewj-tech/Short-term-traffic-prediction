# %%
import matplotlib.pyplot as plt
from scipy.io import loadmat
import numpy as np
from math import sqrt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
def quota(inv_y, inv_yhat,name):
    rmse_ = sqrt(mean_squared_error(inv_y, inv_yhat))
    mae_=mean_absolute_error(inv_y, inv_yhat)
    r2_ = r2_score(inv_y, inv_yhat)
    print(name,'的rmse:', rmse_, ' mae:', mae_, ' R2:', r2_)

# %%
data0=loadmat('结果/elm1_result.mat')['true']
data1=loadmat('结果/elm1_result.mat')['pred']
data2=loadmat('结果/svr1_result.mat')['pred']
data3=loadmat('结果/bp1_result.mat')['pred']
data4=loadmat('结果/lstm_result.mat')['pred']
data5=loadmat('结果/delm_result.mat')['pred']

# %%
print(data0.shape,data1.shape,data2.shape,data3.shape,data4.shape,data5.shape)
# Out:
# (1000, 1) (1000, 1) (1000, 1) (1000, 1) (1000, 1) (1000, 1)

# %%
quota(data0,data1,'ELM')
quota(data0,data2,'SVR')
quota(data0,data3,'BP')
quota(data0,data4,'LSTM')
quota(data0,data5,'DELM')
# Out:
# ELM 的rmse: 15.394306870017328  mae: 12.297761505463269  R2: 0.03777616199696765
# SVR 的rmse: 15.362249803154759  mae: 12.190948802627489  R2: 0.041779454548880324
# BP 的rmse: 15.422763599921653  mae: 12.283672250933746  R2: 0.034215488302691166
# LSTM 的rmse: 15.391683342052058  mae: 12.255135282516479  R2: 0.038104102197298095
# DELM 的rmse: 15.561025793454045  mae: 12.433586790494758  R2: 0.016821714923130004

# %%
# In[7] 画图
plt.figure(figsize=(12,6))
plt.plot(data0,'-',label='real')
plt.plot(data1,'-',label='ELM')
plt.plot(data2,'-',label='SVR')
plt.plot(data3,'-',label='BP')
plt.plot(data4,'-',label='LSTM')
plt.plot(data5,'-',label='DELM')

plt.xlim((0,100))
plt.grid()
plt.legend()
plt.xlabel('Time/h',fontdict={"family":"Times New Roman"})
plt.ylabel('Congestion',fontdict={"family":"Times New Roman"})
plt.savefig('figure/各预测方法对比结果图.png')
plt.show()
