# %%
import matplotlib.pyplot as plt
from scipy.io import loadmat
import numpy as np
from math import sqrt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
def quota(inv_y, inv_yhat,name):
    rmse_ = sqrt(mean_squared_error(inv_y, inv_yhat))
    mae_=mean_absolute_error(inv_y, inv_yhat)
    r2_ = r2_score(inv_y, inv_yhat)
    print(name,'的rmse:', rmse_, ' mae:', mae_, ' R2:', r2_)

# %%
data0=loadmat('结果/bp_result.mat')['true']
data1=loadmat('结果/bp_result.mat')['pred']
data2=loadmat('结果/bp2_result.mat')['pred']
data3=loadmat('结果/bp3_result.mat')['pred']

# %%
print(data0.shape,data1.shape,data2.shape,data3.shape)
# Out:
# (1000, 1) (1000, 1) (1000, 1) (1000, 1)

# %%
quota(data0,data1,'BP')
quota(data0,data2,'BP2')
quota(data0,data3,'BP3')
# Out:
# BP 的rmse: 15.422763599921653  mae: 12.283672250933744  R2: 0.034215488302691166
# BP2 的rmse: 15.383106117141025  mae: 12.308654745937067  R2: 0.0391758626344183
# BP3 的rmse: 15.494913725098774  mae: 12.39428947638004  R2: 0.02515816683986627

# %%
# In[7] 画图
plt.figure(figsize=(12,6))
plt.plot(data0,'-',label='real')
plt.plot(data1,'-',label='BP')
plt.plot(data2,'-',label='BP2')
plt.plot(data3,'-',label='BP3')
plt.xlim((0,100))
# plt.grid()
plt.legend()
plt.xlabel('Time/h',fontdict={"family":"Times New Roman"})
plt.ylabel('Congestion',fontdict={"family":"Times New Roman"})
plt.savefig('figure/BP几种参数下预测结果图.png')
plt.show()
